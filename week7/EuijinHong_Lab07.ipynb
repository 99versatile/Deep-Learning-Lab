# %% [markdown]
# > ### EEE4423: Deep Learning Lab
#
# # LAB #7: High-level Vision - Single Shot Object Detection (YOLO)

# %% [markdown]
# <h4><div style="text-align: right"> Due date: APRIL 21, 2022.  </div> <br>
# <div style="text-align: right"> Please upload your file @ LearnUs by 2 PM in the form of [ID_Name_Lab07.ipynb]. </div></h4>

# %% [markdown]
# ### *Instructions:*
# - Write a program implementing a particular algorithm to solve a given problem.
# - <span style="color:red">**Report and discuss your results. Analyze the algorithm, theoretically and empirically.**</span>
# - Each team must write their own answers and codes (<span style="color:red">**if not you will get a F grade**</span>).

# %% [markdown]
# <h2><span style="color:blue">[2018142102] [Euijin Hong]</span> </h2>

# %%
import datetime
print("This code is written at " + str(datetime.datetime.now()))
# Out:
# This code is written at 2023-04-17 13:38:29.161930

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
import torch.utils.data as data
from torch.autograd import Variable

import torchvision.datasets as dsets

import numpy as np
import cv2

import os
import struct
import copy
import random

import time
import datetime

import math

from PIL import Image
import torchvision.transforms as transforms
from torchvision.transforms import Compose, ToTensor, Resize
from torch.utils import data
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 1. What is the Object Detection?
#
# >
# > <img src="https://drive.google.com/uc?export=view&id=1pOo5As8Qo8bQOQjOkkpRwjVKcKNB4gSE" alt="no_image" style="width: 800px;"/>
# >
# > - The difference between $\bf{classification}$ (left) and $\bf{detection}$ (right) is simple
# >
# > - In image classification, the entire image is classified with a single label
# >
# > - In object detection, the network localizes (potentially multiple) objects within the image
# >
# > - Therefore, given the image, the obejct detection networks ouput a list of bounding box, class label, and **probability/confidence score**
# >
#
# ### 2. About YOLO (Main idea)
#
# >
# > <img src="https://drive.google.com/uc?export=view&id=1K7tvcGXdRHBc_t5p-m3uyRrCBFbJ9ze5" alt="no_image" style="width: 800px;"/>
# >
# > - YOLO is an algorithm for object detection
# >
# > - They reframe object detection as a $\bf{single\ regression\ problem}$, straight from image pixels to bounding box coordinates and class probabilities
# >
# > - Using YOLO, you only look once (YOLO) at an image to predict what objects are present and where they are
# >
# > - The advantage of YOLO is the speed, which is extremely fast, since the authors reframe detection as a regression problem not using a complex pipeline
# >
# > - What are differences between YOLO and previous detectors?? Refer to https://towardsdatascience.com/r-cnn-fast-r-cnn-faster-r-cnn-yolo-object-detection-algorithms-36d53571365e

# %% [markdown]
# ### 3. Building a YOLO with PyTorch
#
# > ### YOLO model:
# > - 22Convolutional Layers
# >
# >     - Note that, first and 20th conv layers have stride 2 for halving output size
# >
# > - 4 Max Pooling Layers
# >
# > - 2 Fully Connected Layers
# >
# > - Leaky ReLu Activation for all layers except for the last layer
#
# ### 4. Implementing YOLO
# >
# > - The input image is divided into an S $\times$ S grid of cells
# >
# > - Each grid cell predicts B (=2) bounding boxes as well as C (=20) class probabilities
# >
# > - Each bounding box consists of 5 predictions: x, y, w, h, and confidence
# >
# > - The (x,y) coordinates represent the center of the box relative to the bounds of the grid cell
# >
# > - The width and height are predicted relative to the whole image
# >
# > - If no object exists in that cell, the confidence score is zero.
# >
# > - If the cell contains objects, the confidence score is equal to the intersection over union (IOU) between the predicted box and the ground truth (**This is important for building the loss function**)
# >
# > - Thus, the output vector is a S $\times$ S $\times$ (B $\times$ 5 + C) (= 7 $\times$ 7 $\times$ 30)
# >
# > <img src="https://drive.google.com/uc?export=view&id=1LdKtTyYjGKKWmu-4nTYBEMI7n4Sk0aeB" alt="no_image" style="width: 600px;"/>
# >
# > - You must study *generate_target* function in detail, it contains the process of generating output vectors
# >
# > Step 1: Load the dataset
# >
# > Step 2: Build the YOLO network ($\bf{4 points}$)
# >>
# >>  <img src="https://drive.google.com/uc?export=view&id=1c4yOWTZacei0_pFoI47wfxVEhM5Tms8X" alt="no_image" style="width: 800px;"/>
# >>
# >> - Following the YOLO model, you build yolo network
# >> - **Note that our model is different from network of original paper. Please follow above figure.**
# >> - You must fill out the blank in **self.pre_train_net** and **self.post_net** blocks
# >> - All layers use the following Leaky ReLU (0.01 slope for negative part - Note that it is different from the paper)
# >>
# >>
# >> #### **self.pre_train_net**
# >>
# >>
# >>
# >>| Name       | Filters              | Output Dimension | Padding |
# >>|------------|----------------------|------------------| ------- |
# >>| Conv 1     | 7 x 7 x 64, stride=2 | 224 x 224 x 64   | 3       |
# >>| LeakyReLU  | negative_slop=0.01   | 224 x 224 x 64   |         |
# >>| Max Pool 1 | 2 x 2, stride=2      | 112 x 112 x 64   |         |
# >>|
# >>| Conv 2     | 3 x 3 x 192          | 112 x 112 x 192  | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 112 x 112 x 192  |         |
# >>| Max Pool 2 | 2 x 2, stride=2      | 56 x 56 x 192    |         |
# >>|
# >>| Conv 3     | 1 x 1 x 128          | 56 x 56 x 128    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 56 x 56 x 128    |         |
# >>| Conv 4     | 3 x 3 x 256          | 56 x 56 x 256    | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 56 x 56 x 256    |         |
# >>| Conv 5     | 1 x 1 x 256          | 56 x 56 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 56 x 56 x 256    |         |
# >>| Conv 6     | 3 x 3 x 512          | 56 x 56 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 56 x 56 x 512    |         |
# >>| Max Pool 3 | 2 x 2, stride=2      | 28 x 28 x 512    |         |
# >>|
# >>| Conv 7     | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 256    |         |
# >>| Conv 8     | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 512    |         |
# >>| Conv 9     | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 256    |         |
# >>| Conv 10    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 512    |         |
# >>| Conv 11    | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 256    |         |
# >>| Conv 12    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 512    |         |
# >>| Conv 13    | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 256    |         |
# >>| Conv 14    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 512    |         |
# >>| Conv 15    | 1 x 1 x 512          | 28 x 28 x 512    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 512    |         |
# >>| Conv 16    | 3 x 3 x 1024         | 28 x 28 x 1024   | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 1024   |         |
# >>| Max Pool 4 | 2 x 2, stride=2      | 14 x 14 x 1024   |         |
# >>|
# >>| Conv 17    | 1 x 1 x 512          | 14 x 14 x 512    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 14 x 14 x 512    |         |
# >>| Conv 18    | 3 x 3 x 1024         | 14 x 14 x 1024   | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 14 x 14 x 1024   |         |
# >>
# >> #### **self.post_net**
# >>
# >>| Name      | Filters                | Output Dimension | Padding |
# >>|-----------|------------------------|------------------| ------- |
# >>| Conv 19   | 3 x 3 x 1024           | 14 x 14 x 1024   | 1       |
# >>| LeakyReLU | negative_slop=0.01     | 14 x 14 x 1024   |         |
# >>| Conv 20   | 3 x 3 x 1024, stride=2 | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.01     | 7 x 7 x 1024     |         |
# >>| Conv 21   | 3 x 3 x 1024           | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.01     | 7 x 7 x 1024     |         |
# >>| Conv 22   | 3 x 3 x 1024           | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.01     | 7 x 7 x 1024     |         |
# >>
# > Step 3: Loss function ($\bf{6 points}$)
# >
# >> - Fill out the code considering the loss function in YOLO
# >> - The loss function is composed like below
# >> <img src="https://drive.google.com/uc?export=view&id=1QcAP__J50M379GAul7SlhAzzU551tuDj" alt="no_image" style="width: 600px;"/>
# >>
# >> - $\mathbb{1}_{obj}$ is defined as follows:
# >>    - 1, if an object is present in grid cell $i$ and the $j$th bounding box predictor
# >>    - 0, otherwise
# >>
# >> - YOLO predicts multiple bounding boxes per grid cell (in our case, 2 bounding boxes are predicted)
# >> - In train stage, YOLO requires one bounding box predictor to be responsible for each object
# >> - The code assigns one predictor to be "responsible" for predicting an object where the predictor has the highest IOU with the ground truth
# >> - The loss function is divided into the three sub-sections
# >>    1. Classification ( $\bf{6}$ classes ) ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=13mnxg_GNtbWnYLpe1P6zopf693zTYe22" alt="no_image" style="width: 300px;"/>
# >>
# >>       - Similar to sum-squared error for classification except for $\mathbb{1}_{obj}$ term
# >>
# >>       - Note that, we do not penalize classification error when no object is present on the cell (by $\mathbb{1}_{obj}$ term)
# >>
# >>    2. No object appears in cell ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=1R74HzbRLoX2K5zun8XSLAnRQlKq25XFV" alt="no_image" style="width: 300px;"/>
# >>
# >>       - Compute the loss associated with the confidence score for each bounding box predictor
# >>
# >>       - $\mathbb{1}_{noobj}$ is equal to one when there is no object in the cell, and 0 other wise
# >>    3. Bounding box coordinates (x,y,h,w) regression (4 scalars), and Object confidence ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=1lXs5lHUiXGxgMRNCiViY6SyRDL52gQsy" alt="no_image" style="width: 600px;"/>
# >>
# >>       - Compute the loss realted to the predicted bounding box position $(x,y)$ and width/height $(w,h)$
# >>
# >>       - Note that width/height are adapted square root before computing the loss
# >>
# >>       - In order to solve the problem that small deviations in large boxes matter less than in small boxes
# >>
# >>       - Compute the loss associated with the confidence score for the cell which is responsible for the object
# >>
# >> - Following the paper, $\lambda_{coord} = 5$ and $\lambda_{noobj} = 0.5$
# >>
# > Step 4: Train Model ($\bf{2 points}$)
# >>
# >> - Based on the above code, you build train code on your own
# >> - The necessary things are provided (e.g., *optimizer* and *num_epoch*)
# >> - Note that, we offer the pre-trained model since it requires large training time.
# >> - If you construct your code correctly, the performance of mAP will be over 0.69 mAP in 10 epochs (about 15 minitues.)
# >>
# > Step 5: Inference
# >>
# >> - We offer the test code in below
# >> - You can check the qualitative results using the visualization code
# >> - The quantitative results will be evaluated by using the mAP code
# >> - If the performance of mAP is significantly decreased from the pre-trained model (0.685 mAP), your code will be wrong
# >>
# >> Step 5-1: Inference (Visualization)
# >>
# >> Step 5-2: Inference (mAP)

# %% [markdown]
# ### Step 1. Load the dataset

# %%
# os.environ["CUDA_VISIBLE_DEVICES"] = "0"

class YoloDataset(data.Dataset):
    def __init__(self, root, list_file, train, transform=None):
        self.image_size = 448
        self.root = root
        self.train = train
        self.transform = transform
        self.fnames = []
        self.boxes = []
        self.labels = []
        self.color_jitter = Compose([transforms.ColorJitter(brightness=0.1,contrast=0.1, saturation=0.1, hue=0.1),
                                                 transforms.ToTensor()])
        self.plain = Compose([transforms.ToTensor()])
        self.resize = Compose([transforms.ToPILImage(),
                              transforms.Resize((self.image_size, self.image_size)),
                              transforms.ToTensor()])
        
        with open(list_file) as f:
            lines = f.readlines()
            
        for line in lines:
            splited = line.strip().split()
            self.fnames.append(splited[0])
            num_boxes = (len(splited) - 1) // 5
            box = []
            label = []
            for i in range(num_boxes):
                x_min = float(splited[1+5*i])
                y_min = float(splited[2+5*i])
                x_max = float(splited[3+5*i])
                y_max = float(splited[4+5*i])
                c = splited[5+5*i]
                box.append([x_min, y_min, x_max, y_max])
                label.append(int(c)+1)
            self.boxes.append(torch.Tensor(box))
            self.labels.append(torch.LongTensor(label))
        self.num_samples = len(self.boxes)
        
    def img_pre_process(self, img, boxes, labels):
        
        if random.random() < 0.5:
            im_lr = np.fliplr(img).copy()
            height, width, c = img.shape
            x_min = width - boxes[:, 2]
            x_max = width - boxes[:, 0]
            boxes[:,0] = x_min
            boxes[:,2] = x_max
            img = im_lr
        
        ## Converting the image and box information scaling
        if random.random() < 0.5:
            scale = random.uniform(0.8, 1.2)
            height, width, c = img.shape
            img = cv2.resize(img, (int(width * scale), height))
            boxes = boxes * torch.FloatTensor([[scale, 1, scale, 1]]).expand_as(boxes)
            
        ## Image translation
        if random.random() < 0.5:
            center = (boxes[:,2:] + boxes[:,:2]) / 2
            height, width, c = img.shape
            shifted_img = np.zeros((height, width, c), dtype=img.dtype)
            
            w_range = int(random.uniform(-width*0.2, width*0.2))
            h_range = int(random.uniform(-height*0.2, height*0.2))
            
            if w_range<0 and h_range<0:
                shifted_img[:height+h_range,:width+w_range,:] = img[-h_range:,-w_range:,:]
                
            elif w_range<0 and h_range>=0:
                shifted_img[h_range:,:width+w_range,:] = img[:height-h_range,-w_range:,:]
            
            elif w_range>=0 and h_range>=0:
                shifted_img[h_range:,w_range:,:] = img[:height-h_range,:width-w_range,:]
                
            elif w_range>=0 and h_range<0:
                shifted_img[:height+h_range,w_range:,:] = img[-h_range:,:width-w_range,:]
                
            wh_range = torch.FloatTensor([[w_range, h_range]]).expand_as(center)
            center = center + wh_range
            
            mask1 = (center[:,0] > 0) & (center[:,0] < width)
            mask2 = (center[:,1] > 0) & (center[:,1] < height)
            mask = (mask1 & mask2).view(-1,1).bool()
            
            boxes_in = boxes[mask.expand_as(boxes)].view(-1,4)
            
            if len(boxes_in) != 0:
                box_shift = torch.FloatTensor([[w_range, h_range, w_range, h_range]]).expand_as(boxes_in)
                boxes_in = boxes_in + box_shift
                
                labels_in = labels[mask.view(-1)]
                labels = labels_in
                img = shifted_img
                boxes = boxes_in
        
        ## Image cropping
        if random.random() < 0.5:
            center = (boxes[:,2:] + boxes[:,:2]) / 2
            height, width, c = img.shape
            h = int(random.uniform(0.6*height,height))
            w = int(random.uniform(0.6*width,width))
            x = int(random.uniform(0,width-w))
            y = int(random.uniform(0,height-h))
            
            center = center - torch.FloatTensor([[x, y]]).expand_as(center)
            mask1 = (center[:,0]>0) & (center[:,0]<w)
            mask2 = (center[:,1]>0) & (center[:,1]<h)
            mask = (mask1 & mask2).view(-1, 1).bool()
            
            boxes_in = boxes[mask.expand_as(boxes)].view(-1,4)
            
            if (len(boxes_in)!=0):
                box_shift = torch.FloatTensor([x,y,x,y]).expand_as(boxes_in)

                boxes_in = boxes_in - box_shift
                boxes_in[:,0]=boxes_in[:,0].clamp_(min=0,max=w)
                boxes_in[:,2]=boxes_in[:,2].clamp_(min=0,max=w)
                boxes_in[:,1]=boxes_in[:,1].clamp_(min=0,max=h)
                boxes_in[:,3]=boxes_in[:,3].clamp_(min=0,max=h)

                labels = labels[mask.view(-1)]
                img_cropped = img[y:y+h, x:x+w, :]
                boxes = boxes_in
                img = img_cropped
        
        return img, boxes, labels

    def generate_target(self, img, boxes, labels):
        grid_size = 7
        h,w,_ = img.shape
        boxes /= torch.Tensor([w,h,w,h]).expand_as(boxes) # Converting the box size 0 ~ 1
        target = torch.zeros((grid_size, grid_size, 30)) 
        cell_size = 1./grid_size 

        wh = boxes[:,2:] - boxes[:,:2]
        cxcy = (boxes[:,2:] + boxes[:,:2]) / 2
        
        for i in range(cxcy.size()[0]):
            cxcy_sample = cxcy[i] # center pixel 
            ij = (cxcy_sample/cell_size).ceil()-1 
            target[int(ij[1]),int(ij[0]),4] = 1
            target[int(ij[1]),int(ij[0]),9] = 1
            target[int(ij[1]),int(ij[0]),int(labels[i])+9] = 1
            
            xy = ij*cell_size 
            delta_xy = (cxcy_sample -xy)/cell_size # Converting delta_xy to the size 
                                                   # relative to the bounds of the grid cell
            target[int(ij[1]),int(ij[0]),2:4] = wh[i]
            target[int(ij[1]),int(ij[0]),:2] = delta_xy
            target[int(ij[1]),int(ij[0]),7:9] = wh[i]
            target[int(ij[1]),int(ij[0]),5:7] = delta_xy
            
        return target
    
    def RandomBrightness(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            v = v*adjust
            v = np.clip(v, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr
    def RandomSaturation(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            s = s*adjust
            s = np.clip(s, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr
    def RandomHue(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            h = h*adjust
            h = np.clip(h, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr

    def randomBlur(self,bgr):
        if random.random()<0.5:
            bgr = cv2.blur(bgr,(5,5))
        return bgr
        
    def __getitem__(self, idx):
        fname = self.fnames[idx]
        img = cv2.imread(os.path.join(self.root+fname))
        boxes = self.boxes[idx].clone()
        labels = self.labels[idx].clone()

        if self.train:
            img = self.randomBlur(img)
            img = self.RandomBrightness(img)
            img = self.RandomHue(img)
            img = self.RandomSaturation(img)
            img, boxes, labels = self.img_pre_process(img, boxes, labels)
            
        target = self.generate_target(img, boxes, labels) # 7x7x30
        
        # Image processing
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        img = self.plain(img)
        img = self.resize(img)
        img = 2 * img - 1
        
        return img, target
    
    def __len__(self):
        return self.num_samples

# %% [markdown]
# ### Step 2. Build the YOLO network (2 points)

# %% [markdown]
# > You should build model using nn.Sequential. Otherwise, problem arises when loading pretrained weights.

# %%
class YOLO(nn.Module):
    def __init__(self):
        super(YOLO, self).__init__()
        
        self.pre_train_net = nn.Sequential(
            ################
            ### Fill out ###
            ################
            
            # Conv1, LeakyReLU, MaxPool1
            nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3), 
            nn.LeakyReLU(negative_slope=0.01), 
            nn.MaxPool2d(2, stride=2), 
            
            # Conv2, LeakyReLU, MaxPool2
            nn.Conv2d(64, 192, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.01), 
            nn.MaxPool2d(2, stride=2), 
            
            # Conv3, LeakyReLU
            nn.Conv2d(192, 128, kernel_size=1, stride=1, padding=0), 
            nn.LeakyReLU(negative_slope=0.01), 
            
            # Conv4, LeakyReLU
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1), 
            nn.LeakyReLU(negative_slope=0.01), 
            
            # Conv5, LeakyReLU
            nn.Conv2d(256, 256, kernel_size=1, stride=1, padding=0), 
            nn.LeakyReLU(negative_slope=0.01), 
            
            # Conv6, LeakyReLU, MaxPool3
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.01), 
            nn.MaxPool2d(2, stride=2),
            
            # Conv7, LeakyReLU
            nn.Conv2d(512, 256, kernel_size=1, stride=1, padding=0), 
            nn.LeakyReLU(negative_slope=0.01), 
            
            # Conv8, LeakyReLU
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.01), 
            
            # Conv9, LeakyReLU
            nn.Conv2d(512, 256, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope=0.01), 
            
            # Conv10, LeakyReLU
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1), 
            nn.LeakyReLU(negative_slope=0.01), 
            
            # Conv11, LeakyReLU
            nn.Conv2d(512, 256, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope=0.01), 
            
            # Conv12, LeakyReLU
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.01), 
            
            # Conv13, LeakyReLU
            nn.Conv2d(512, 256, kernel_size=1, stride=1, padding=0), 
            nn.LeakyReLU(negative_slope=0.01), 
            
            # Conv14, LeakyReLU
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.01), 
            
            # Conv15, LeakyReLU
            nn.Conv2d(512, 512, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope=0.01), 
            
            # Conv16, LeakyReLU, MaxPool4
            nn.Conv2d(512, 1024, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.01), 
            nn.MaxPool2d(2, stride=2), 
            
            # Conv17, LeakyReLU
            nn.Conv2d(1024, 512, kernel_size=1, stride=1, padding=0), 
            nn.LeakyReLU(negative_slope=0.01), 
            
            # Conv18, LeakyReLU
            nn.Conv2d(512, 1024, kernel_size=3, stride=1, padding=1), 
            nn.LeakyReLU(negative_slope=0.01)
        )
        
        self.post_net = nn.Sequential(
            ################
            ### Fill out ###
            ################
            
            # Conv19, LeakyReLU
            nn.Conv2d(1024, 1024, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.01), 
            
            # Conv20, LeakyReLU
            nn.Conv2d(1024, 1024, kernel_size=3, stride=2, padding=1),
            nn.LeakyReLU(negative_slope=0.01), 
            
            # Conv21, LeakyReLU
            nn.Conv2d(1024, 1024, kernel_size=3, stride=1, padding=1), 
            nn.LeakyReLU(negative_slope=0.01), 
            
            # Conv22, LeakyReLU
            nn.Conv2d(1024, 1024, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.01)
        )
        
        self.FC1 = nn.Sequential(
            nn.Linear(50176, 4096),
            nn.LeakyReLU(),
            nn.Dropout()
        )
        
        self.FC2 = nn.Sequential(
            nn.Linear(4096, 1470)
        )
        
        self.pre_train_net.cuda()
        self.post_net.cuda()
        self.FC1.cuda()
        self.FC2.cuda()
        
        self._initialize_weights()

    def forward(self, x):
        output = self.pre_train_net(x)
        output = self.post_net(output)

        # Ready to going for FC layer
        output = output.view(output.size(0), -1)

        output = self.FC1(output)
        output = self.FC2(output)

        output = output.view(output.size(0), 7, 7, 30)
        # Converting the output shape to the (batch_size, 7, 7, 30)
        output = F.relu(output)

        return output
    
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_()

# %% [markdown]
# ### Step 3. Loss function (6 points)

# %%
class yoloLoss(nn.Module):
    def __init__(self,l_coord,l_noobj):
        super(yoloLoss,self).__init__()
        self.l_coord = l_coord
        self.l_noobj = l_noobj
    
    def compute_prob_error(self, pred, target): ## classification error
        contain = target[:,:,:,4] > 0 # [Batch_size, 7, 7, 1]
        contain = contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]
        
        ################
        ### Fill out ###
        ################
        
        contain_pred = pred[contain].contiguous().view(-1,30) # Only cell which contains the object are remained (1_obj): contain x 30
        class_pred = contain_pred[:,10:].contiguous() # extract class probability of prediction (pc): contain x 20
        
        contain_target = target[contain].contiguous().view(-1,30) # Only cell which contains the object are remained (1_obj): contain x 30
        class_target = contain_target[:,10:].contiguous() # extract class probability of target (pc): contain x 20
        
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # Move tensor to GPU to calculate class probability loss
        prob_loss = F.mse_loss(class_pred.to(device), class_target.to(device), size_average=False) # applying sum squared error by MSEloss with size average = False
        
        return prob_loss
    
    def not_contain_obj_error(self, pred, target): ## Error where no object appears in cell
        not_contain = target[:,:,:,4] == 0 # [Batch_size, 7, 7, 1]
        not_contain = not_contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]
        
        ################
        ### Fill out ###
        ################
        
        not_contain_pred = pred[not_contain].contiguous().view(-1, 30) # Only the cells which do not contain the object remains(partial 1_noobj): not_contain x 30
        not_box_pred = not_contain_pred[:, :10].contiguous().view(-1, 5) # Getting data of two bounding boxes and reshaping: not_contain x 10 -> not_contain*2 x 5
        not_pred_conf = not_box_pred[:, 4].view(-1, 1) # Extract the confidence score of prediction: not_contain*2 x 1
        
        not_contain_target = target[not_contain].contiguous().view(-1, 30) # Only the cells which do not contain the object remains(partial 1_noobj): not_contain x 30
        not_box_target = not_contain_target[:, :10].contiguous().view(-1, 5) # Getting data of two bounding boxes and reshaping: not_contain x 10 -> not_contain*2 x 5
        not_target_conf = not_box_target[:, 4].view(-1, 1) # Extract the confidence score of target: not_contain*2 x 1
        
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # Move tensor to GPU to calculate noobj confidence score loss
        noobj_loss1 = F.mse_loss(not_pred_conf.to(device), not_target_conf.to(device), size_average=False) # applying sum squared error by MSEloss with size average = False
        return noobj_loss1
    
    
    def contain_obj_error(self, pred, target): ##
        contain = target[:,:,:,4] > 0 # [Batch_size, 7, 7, 1]
        contain = contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]
        contain_pred = pred[contain].contiguous().view(-1,30) # Only cell which contains the object are remained contain x 30
        box_pred = contain_pred[:,:10].contiguous().view(-1,5) # Reshaping contain x 10 -> contain*2 x 5
        
        contain_target = target[contain].contiguous().view(-1,30)
        box_target = contain_target[:,:10].contiguous().view(-1,5) # contain x 10 -> contain*2 x 5
        
        
        # Note that, We assign one predictor to be "responsible" for predicting 
        # an object based on which prediction has the highest current IOU with the ground truth
        # Then, other prediction is "not responsible" for predicting an object
        # That component is included in "contain_noobj_mask variables
        
        contain_obj_mask = torch.cuda.ByteTensor(box_target.size()).zero_().bool() # Create the mask -> Bs*98 x 5
        contain_noobj_mask = torch.cuda.ByteTensor(box_target.size()).zero_().bool() 
        target_iou_gt = torch.zeros(box_target[:,0].size()).cuda() # In order to save the IoU for confidence 
                                                                   # of the cell which contains object -> Bs*98 x 1
        
        for i in range(0, box_target.size()[0], 2):
            box_p = box_pred[i:i+2] # For 2 bounding boxes information
            box_p_coord = Variable(torch.FloatTensor(box_p.size())) # Box coordinate (x_min, y_min, x_max, y_max)
            # assign prediction box coordinates x_min, y_min
            box_p_coord[:,:2] = torch.cat(((box_p[:,0]-box_p[:,2]/2).unsqueeze(1), (box_p[:,1]-box_p[:,3]/2).unsqueeze(1)), 1)  ## Fill out
            # assign prediction box coordinates x_max, y_max
            box_p_coord[:,2:4] = torch.cat(((box_p[:,0]+box_p[:,2]/2).unsqueeze(1), (box_p[:,1]+box_p[:,3]/2).unsqueeze(1)), 1)  ## Fill out
            
            box_t = box_target[i].contiguous().view(-1,5) # 49 x 1
            box_t_coord = Variable(torch.FloatTensor(box_t.size()))
            # assign target box coordinates x_min, y_min
            box_t_coord[:,:2] = torch.cat(((box_t[:,0]-box_t[:,2]/2).unsqueeze(1), (box_t[:,1]-box_t[:,3]/2).unsqueeze(1)), 1)  ## Fill out
            # assign target box coordinates x_max, y_max
            box_t_coord[:,2:4] = torch.cat(((box_t[:,0]+box_t[:,2]/2).unsqueeze(1), (box_t[:,1]+box_t[:,3]/2).unsqueeze(1)), 1)  ## Fill out
            
            iou = self.compute_iou(box_p_coord[:,:4], box_t_coord[:,:4]) # [2,]
                                                      # compute IoU between prediction and target boxes, 
            
            gt_iou, max_idx = iou.max(0)
            contain_obj_mask[i+max_idx] = 1
            contain_noobj_mask[i+1-max_idx] = 1
            
            target_iou_gt[i+max_idx] = gt_iou.data.cuda()
            
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        target_iou_gt = target_iou_gt.to(device)
        
        
        ## For the cell which contains object that are 'responsible' to detection
        contain_box_pred = box_pred[contain_obj_mask].contiguous().view(-1,5).to(device)  # leaving box predictions that contain obj   ## Fill out 

        ## For the cell which does not contain object that are 'not responsible' to detection
        not_contain_box_pred = box_pred[contain_noobj_mask].contiguous().view(-1,5).to(device)  # leaving box predictions that does not contain obj   ## Fill out 

        ## For target domain: cells that are 'responsible' and 'not responsible' to detection
        contain_box_target = box_target[contain_obj_mask].contiguous().view(-1,5).to(device)  # leaving box target that contain obj   ## Fill out
        not_contain_box_target = box_target[contain_noobj_mask].contiguous().view(-1,5).to(device)  # leaving box target that does not contain obj   ## Fill out
        not_contain_box_target[:,4] = 0  # confidence of noobj box = 0
        
        ## For the GT IoU : remain the ground truth IOU for cells that are 'responsible' to detection
        contain_iou_target = target_iou_gt[contain_obj_mask[:,4]].contiguous() #   ## Fill out 
        
        obj_loss = F.mse_loss(contain_box_pred[:,4], contain_iou_target, size_average=False)
        xy_loss = F.mse_loss(contain_box_pred[:,:2], contain_box_target[:,:2], size_average=False)
        wh_loss = F.mse_loss(torch.sqrt(contain_box_pred[:,2:4]), torch.sqrt(contain_box_target[:,2:4]), size_average=False)
        noobj_loss2 = F.mse_loss(not_contain_box_pred[:,4], not_contain_box_target[:,4], size_average=False)
        return obj_loss, xy_loss, wh_loss, noobj_loss2
        
    def compute_iou(self, box_p, box_t):
        
        pred_area = (box_p[:,2] - box_p[:,0]) * (box_p[:,3] - box_p[:,1]) # [2,]
        target_area = (box_t[:,2] - box_t[:,0]) * (box_t[:,3] - box_t[:,1]) #[1,]
        
        box_p = box_p.unsqueeze(1).expand(2,1,4)
        box_t = box_t.unsqueeze(0).expand(2,1,4)
        
        inter_lt = torch.max(box_p[:,:,:2], box_t[:,:,:2]) # [2,1,2]
        
        inter_rb = torch.min(box_p[:,:,2:], box_t[:,:,2:]) # [2,1,2]
        
        wh = inter_rb - inter_lt # [2,1,2]
        wh[wh<0] = 0 
        
        inter_area = wh[:,:,0] * wh[:,:,1] # [2,1]
        pred_area = pred_area.unsqueeze(1).expand_as(inter_area)
        target_area = target_area.unsqueeze(0).expand_as(inter_area)
        
        iou = inter_area / (pred_area + target_area - inter_area)
        
        return iou
    
        
    
    def forward(self,pred,target):

        batch_size = pred.size()[0]
        
        noobj_loss1 = self.not_contain_obj_error(pred, target)
        prob_loss = self.compute_prob_error(pred, target)
        obj_loss, xy_loss, wh_loss, noobj_loss2 = self.contain_obj_error(pred, target)
        
        total_loss = (self.l_coord*(xy_loss + wh_loss) + obj_loss + self.l_noobj*(noobj_loss1 + noobj_loss2) + prob_loss)
        
        return total_loss / batch_size

# %% [markdown]
# ### Step 4. Train the model

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
file_root = './dataset-dllab/lab07/all_img/'
train_dataset = YoloDataset(root=file_root, list_file='./misc/lab07/Generate_dataset/voc2007+2012.txt', train=True)
train_loader = DataLoader(train_dataset, batch_size=10, shuffle=True, num_workers=4)

model = YOLO()
state_dict = torch.load('./pretrain/lab07/pre_train.pt')
model.load_state_dict(state_dict['state_dict'])
print('pre_train_complete')

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

learning_rate = 1e-4
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)
optimizer.load_state_dict(state_dict['optimizer'])

criterion = yoloLoss(l_coord=5,l_noobj=0.5)

best = 0.5
num_epochs = 15
print("training start!")

torch.autograd.set_detect_anomaly(True)
for epoch in range(num_epochs):
    model.train()
    total_loss = 0
        
    for i, (images, target) in enumerate(train_loader):
        images = images.to(device)
        target = target.to(device)
        
        pred = model(images)
        loss = criterion(pred, target)
        
        total_loss += loss.item()
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i+1) % 10 == 0:
            print('Epoch [%d/%d], Iter [%d,%d] Loss:%.4f, average_loss: %.4f' % (epoch+1, num_epochs, i+1, len(train_loader), loss.item(), total_loss / (i+1)))
            if epoch > 5 and total_loss / (i+1) < best:
                best = total_loss / (i+1)
                torch.save(model, './weights/lab07/best.pt')
            if epoch == 4 and i+1 == 430:
                torch.save(model, "./weights/lab07/epoch5.pt")
            if epoch == 9 and i+1 == 430:
                torch.save(model, "./weights/lab07/epoch10.pt")
            if epoch == 14 and i+1 == 430:
                torch.save(model, "./weights/lab07/epoch15.pt")
# Out:
# pre_train_complete
# training start!
# Epoch [1/15], Iter [10,430] Loss:0.3428, average_loss: 0.6736
# Epoch [1/15], Iter [20,430] Loss:0.4070, average_loss: 0.6192
# Epoch [1/15], Iter [30,430] Loss:0.2913, average_loss: 0.5955
# Epoch [1/15], Iter [40,430] Loss:0.7771, average_loss: 0.6320
# Epoch [1/15], Iter [50,430] Loss:0.5368, average_loss: 0.6245
# Epoch [1/15], Iter [60,430] Loss:0.4937, average_loss: 0.6136
# Epoch [1/15], Iter [70,430] Loss:0.4881, average_loss: 0.5982
# Epoch [1/15], Iter [80,430] Loss:1.1923, average_loss: 0.6022
# Epoch [1/15], Iter [90,430] Loss:0.3987, average_loss: 0.6048
# Epoch [1/15], Iter [100,430] Loss:0.7468, average_loss: 0.6176
# Epoch [1/15], Iter [110,430] Loss:0.3245, average_loss: 0.6340
# Epoch [1/15], Iter [120,430] Loss:0.2761, average_loss: 0.6240
# Epoch [1/15], Iter [130,430] Loss:1.1610, average_loss: 0.6281
# Epoch [1/15], Iter [140,430] Loss:0.4907, average_loss: 0.6258
# Epoch [1/15], Iter [150,430] Loss:0.4753, average_loss: 0.6181
# Epoch [1/15], Iter [160,430] Loss:1.0035, average_loss: 0.6268
# Epoch [1/15], Iter [170,430] Loss:0.4426, average_loss: 0.6254
# Epoch [1/15], Iter [180,430] Loss:0.3124, average_loss: 0.6215
# Epoch [1/15], Iter [190,430] Loss:1.2869, average_loss: 0.6260
# Epoch [1/15], Iter [200,430] Loss:0.5010, average_loss: 0.6219
# Epoch [1/15], Iter [210,430] Loss:0.4828, average_loss: 0.6247
# Epoch [1/15], Iter [220,430] Loss:0.4436, average_loss: 0.6206
# Epoch [1/15], Iter [230,430] Loss:0.5198, average_loss: 0.6214
# Epoch [1/15], Iter [240,430] Loss:0.4579, average_loss: 0.6188
# Epoch [1/15], Iter [250,430] Loss:0.2579, average_loss: 0.6191
# Epoch [1/15], Iter [260,430] Loss:0.2566, average_loss: 0.6210
# Epoch [1/15], Iter [270,430] Loss:0.3412, average_loss: 0.6175
# Epoch [1/15], Iter [280,430] Loss:0.2566, average_loss: 0.6152
# Epoch [1/15], Iter [290,430] Loss:0.5143, average_loss: 0.6109
# Epoch [1/15], Iter [300,430] Loss:0.3196, average_loss: 0.6080
# Epoch [1/15], Iter [310,430] Loss:0.2809, average_loss: 0.6077
# Epoch [1/15], Iter [320,430] Loss:0.3243, average_loss: 0.6063
# Epoch [1/15], Iter [330,430] Loss:0.4561, average_loss: 0.6050
# Epoch [1/15], Iter [340,430] Loss:0.3375, average_loss: 0.6008
# Epoch [1/15], Iter [350,430] Loss:0.3058, average_loss: 0.5989
# Epoch [1/15], Iter [360,430] Loss:0.5551, average_loss: 0.5984
# Epoch [1/15], Iter [370,430] Loss:0.5114, average_loss: 0.5974
# Epoch [1/15], Iter [380,430] Loss:0.5638, average_loss: 0.5980
# Epoch [1/15], Iter [390,430] Loss:0.5072, average_loss: 0.5980
# Epoch [1/15], Iter [400,430] Loss:0.4990, average_loss: 0.5935
# Epoch [1/15], Iter [410,430] Loss:0.5380, average_loss: 0.5915
# Epoch [1/15], Iter [420,430] Loss:1.2619, average_loss: 0.5940
# Epoch [1/15], Iter [430,430] Loss:0.7175, average_loss: 0.5920
# Epoch [2/15], Iter [10,430] Loss:0.6609, average_loss: 0.5545
# Epoch [2/15], Iter [20,430] Loss:0.6631, average_loss: 0.5518
# Epoch [2/15], Iter [30,430] Loss:0.6546, average_loss: 0.5394
# Epoch [2/15], Iter [40,430] Loss:0.2808, average_loss: 0.5283
# Epoch [2/15], Iter [50,430] Loss:0.3700, average_loss: 0.5231
# Epoch [2/15], Iter [60,430] Loss:0.4024, average_loss: 0.5280
# Epoch [2/15], Iter [70,430] Loss:0.2771, average_loss: 0.5227
# Epoch [2/15], Iter [80,430] Loss:0.2843, average_loss: 0.5297
# Epoch [2/15], Iter [90,430] Loss:0.4231, average_loss: 0.5308
# Epoch [2/15], Iter [100,430] Loss:0.2847, average_loss: 0.5431
# Epoch [2/15], Iter [110,430] Loss:0.2957, average_loss: 0.5326
# Epoch [2/15], Iter [120,430] Loss:0.5735, average_loss: 0.5352
# Epoch [2/15], Iter [130,430] Loss:0.2384, average_loss: 0.5403
# Epoch [2/15], Iter [140,430] Loss:0.8981, average_loss: 0.5463
# Epoch [2/15], Iter [150,430] Loss:0.9482, average_loss: 0.5448
# Epoch [2/15], Iter [160,430] Loss:0.5070, average_loss: 0.5479
# Epoch [2/15], Iter [170,430] Loss:0.6249, average_loss: 0.5472
# Epoch [2/15], Iter [180,430] Loss:0.4834, average_loss: 0.5432
# Epoch [2/15], Iter [190,430] Loss:0.6482, average_loss: 0.5472
# Epoch [2/15], Iter [200,430] Loss:0.4307, average_loss: 0.5450
# Epoch [2/15], Iter [210,430] Loss:1.5136, average_loss: 0.5462
# Epoch [2/15], Iter [220,430] Loss:0.9543, average_loss: 0.5491
# Epoch [2/15], Iter [230,430] Loss:0.5949, average_loss: 0.5521
# Epoch [2/15], Iter [240,430] Loss:0.3987, average_loss: 0.5498
# Epoch [2/15], Iter [250,430] Loss:0.8847, average_loss: 0.5521
# Epoch [2/15], Iter [260,430] Loss:0.9866, average_loss: 0.5554
# Epoch [2/15], Iter [270,430] Loss:1.1560, average_loss: 0.5590
# Epoch [2/15], Iter [280,430] Loss:0.4236, average_loss: 0.5602
# Epoch [2/15], Iter [290,430] Loss:0.9682, average_loss: 0.5588
# Epoch [2/15], Iter [300,430] Loss:0.4052, average_loss: 0.5629
# Epoch [2/15], Iter [310,430] Loss:0.4404, average_loss: 0.5633
# Epoch [2/15], Iter [320,430] Loss:0.5872, average_loss: 0.5663
# Epoch [2/15], Iter [330,430] Loss:0.5374, average_loss: 0.5657
# Epoch [2/15], Iter [340,430] Loss:0.8757, average_loss: 0.5653
# Epoch [2/15], Iter [350,430] Loss:0.7865, average_loss: 0.5625
# Epoch [2/15], Iter [360,430] Loss:0.6260, average_loss: 0.5631
# Epoch [2/15], Iter [370,430] Loss:0.8292, average_loss: 0.5647
# Epoch [2/15], Iter [380,430] Loss:0.3959, average_loss: 0.5642
# Epoch [2/15], Iter [390,430] Loss:0.5493, average_loss: 0.5652
# Epoch [2/15], Iter [400,430] Loss:0.6168, average_loss: 0.5679
# Epoch [2/15], Iter [410,430] Loss:0.2938, average_loss: 0.5686
# Epoch [2/15], Iter [420,430] Loss:0.3832, average_loss: 0.5661
# Epoch [2/15], Iter [430,430] Loss:0.7891, average_loss: 0.5647
# Epoch [3/15], Iter [10,430] Loss:0.6319, average_loss: 0.6416
# Epoch [3/15], Iter [20,430] Loss:0.2995, average_loss: 0.6219
# Epoch [3/15], Iter [30,430] Loss:0.6149, average_loss: 0.5734
# Epoch [3/15], Iter [40,430] Loss:0.4081, average_loss: 0.5539
# Epoch [3/15], Iter [50,430] Loss:0.4161, average_loss: 0.5451
# Epoch [3/15], Iter [60,430] Loss:0.5704, average_loss: 0.5306
# Epoch [3/15], Iter [70,430] Loss:0.5494, average_loss: 0.5559
# Epoch [3/15], Iter [80,430] Loss:0.3809, average_loss: 0.5412
# Epoch [3/15], Iter [90,430] Loss:0.3191, average_loss: 0.5360
# Epoch [3/15], Iter [100,430] Loss:0.6867, average_loss: 0.5348
# Epoch [3/15], Iter [110,430] Loss:0.2405, average_loss: 0.5367
# Epoch [3/15], Iter [120,430] Loss:0.4421, average_loss: 0.5404
# Epoch [3/15], Iter [130,430] Loss:0.3056, average_loss: 0.5374
# Epoch [3/15], Iter [140,430] Loss:0.4295, average_loss: 0.5492
# Epoch [3/15], Iter [150,430] Loss:0.3884, average_loss: 0.5552
# Epoch [3/15], Iter [160,430] Loss:0.3678, average_loss: 0.5556
# Epoch [3/15], Iter [170,430] Loss:0.4314, average_loss: 0.5604
# Epoch [3/15], Iter [180,430] Loss:0.5916, average_loss: 0.5610
# Epoch [3/15], Iter [190,430] Loss:0.4696, average_loss: 0.5633
# Epoch [3/15], Iter [200,430] Loss:0.7491, average_loss: 0.5665
# Epoch [3/15], Iter [210,430] Loss:0.7233, average_loss: 0.5689
# Epoch [3/15], Iter [220,430] Loss:0.4575, average_loss: 0.5720
# Epoch [3/15], Iter [230,430] Loss:0.8006, average_loss: 0.5726
# Epoch [3/15], Iter [240,430] Loss:0.4424, average_loss: 0.5777
# Epoch [3/15], Iter [250,430] Loss:0.4526, average_loss: 0.5763
# Epoch [3/15], Iter [260,430] Loss:0.8470, average_loss: 0.5755
# Epoch [3/15], Iter [270,430] Loss:0.6161, average_loss: 0.5770
# Epoch [3/15], Iter [280,430] Loss:0.9084, average_loss: 0.5781
# Epoch [3/15], Iter [290,430] Loss:0.5620, average_loss: 0.5723
# Epoch [3/15], Iter [300,430] Loss:1.0823, average_loss: 0.5709
# Epoch [3/15], Iter [310,430] Loss:0.9865, average_loss: 0.5708
# Epoch [3/15], Iter [320,430] Loss:0.5773, average_loss: 0.5683
# Epoch [3/15], Iter [330,430] Loss:0.4059, average_loss: 0.5688
# Epoch [3/15], Iter [340,430] Loss:0.5031, average_loss: 0.5689
# Epoch [3/15], Iter [350,430] Loss:0.4022, average_loss: 0.5681
# Epoch [3/15], Iter [360,430] Loss:0.3328, average_loss: 0.5670
# Epoch [3/15], Iter [370,430] Loss:0.6780, average_loss: 0.5695
# Epoch [3/15], Iter [380,430] Loss:0.9646, average_loss: 0.5691
# Epoch [3/15], Iter [390,430] Loss:0.4138, average_loss: 0.5678
# Epoch [3/15], Iter [400,430] Loss:0.6634, average_loss: 0.5676
# Epoch [3/15], Iter [410,430] Loss:0.3192, average_loss: 0.5637
# Epoch [3/15], Iter [420,430] Loss:0.7409, average_loss: 0.5651
# Epoch [3/15], Iter [430,430] Loss:0.7906, average_loss: 0.5687
# Epoch [4/15], Iter [10,430] Loss:0.5020, average_loss: 0.4066
# Epoch [4/15], Iter [20,430] Loss:0.4127, average_loss: 0.5654
# Epoch [4/15], Iter [30,430] Loss:0.2661, average_loss: 0.5595
# Epoch [4/15], Iter [40,430] Loss:0.4534, average_loss: 0.5699
# Epoch [4/15], Iter [50,430] Loss:0.3157, average_loss: 0.5667
# Epoch [4/15], Iter [60,430] Loss:0.5874, average_loss: 0.5728
# Epoch [4/15], Iter [70,430] Loss:0.4206, average_loss: 0.5588
# Epoch [4/15], Iter [80,430] Loss:0.8730, average_loss: 0.5615
# Epoch [4/15], Iter [90,430] Loss:0.4776, average_loss: 0.5468
# Epoch [4/15], Iter [100,430] Loss:0.5206, average_loss: 0.5322
# Epoch [4/15], Iter [110,430] Loss:0.6198, average_loss: 0.5353
# Epoch [4/15], Iter [120,430] Loss:0.6755, average_loss: 0.5292
# Epoch [4/15], Iter [130,430] Loss:0.7922, average_loss: 0.5414
# Epoch [4/15], Iter [140,430] Loss:0.3525, average_loss: 0.5365
# Epoch [4/15], Iter [150,430] Loss:0.4073, average_loss: 0.5331
# Epoch [4/15], Iter [160,430] Loss:0.7416, average_loss: 0.5349
# Epoch [4/15], Iter [170,430] Loss:1.2469, average_loss: 0.5426
# Epoch [4/15], Iter [180,430] Loss:0.4024, average_loss: 0.5399
# Epoch [4/15], Iter [190,430] Loss:0.5351, average_loss: 0.5403
# Epoch [4/15], Iter [200,430] Loss:0.2670, average_loss: 0.5375
# Epoch [4/15], Iter [210,430] Loss:0.4097, average_loss: 0.5373
# Epoch [4/15], Iter [220,430] Loss:0.5519, average_loss: 0.5393
# Epoch [4/15], Iter [230,430] Loss:0.3617, average_loss: 0.5399
# Epoch [4/15], Iter [240,430] Loss:0.4100, average_loss: 0.5416
# Epoch [4/15], Iter [250,430] Loss:0.3008, average_loss: 0.5414
# Epoch [4/15], Iter [260,430] Loss:0.9218, average_loss: 0.5458
# Epoch [4/15], Iter [270,430] Loss:0.3081, average_loss: 0.5406
# Epoch [4/15], Iter [280,430] Loss:0.2777, average_loss: 0.5373
# Epoch [4/15], Iter [290,430] Loss:0.4339, average_loss: 0.5346
# Epoch [4/15], Iter [300,430] Loss:0.4047, average_loss: 0.5352
# Epoch [4/15], Iter [310,430] Loss:0.8413, average_loss: 0.5358
# Epoch [4/15], Iter [320,430] Loss:0.3644, average_loss: 0.5361
# Epoch [4/15], Iter [330,430] Loss:0.5172, average_loss: 0.5331
# Epoch [4/15], Iter [340,430] Loss:0.4100, average_loss: 0.5353
# Epoch [4/15], Iter [350,430] Loss:0.2950, average_loss: 0.5348
# Epoch [4/15], Iter [360,430] Loss:0.4372, average_loss: 0.5317
# Epoch [4/15], Iter [370,430] Loss:0.4025, average_loss: 0.5340
# Epoch [4/15], Iter [380,430] Loss:0.7792, average_loss: 0.5368
# Epoch [4/15], Iter [390,430] Loss:0.2726, average_loss: 0.5379
# Epoch [4/15], Iter [400,430] Loss:0.2407, average_loss: 0.5366
# Epoch [4/15], Iter [410,430] Loss:0.4560, average_loss: 0.5365
# Epoch [4/15], Iter [420,430] Loss:0.6112, average_loss: 0.5380
# Epoch [4/15], Iter [430,430] Loss:0.7414, average_loss: 0.5399
# Epoch [5/15], Iter [10,430] Loss:0.2648, average_loss: 0.4505
# Epoch [5/15], Iter [20,430] Loss:0.7417, average_loss: 0.5243
# Epoch [5/15], Iter [30,430] Loss:0.4066, average_loss: 0.5486
# Epoch [5/15], Iter [40,430] Loss:0.5804, average_loss: 0.5561
# Epoch [5/15], Iter [50,430] Loss:0.2078, average_loss: 0.5616
# Epoch [5/15], Iter [60,430] Loss:0.5374, average_loss: 0.5735
# Epoch [5/15], Iter [70,430] Loss:0.5464, average_loss: 0.5651
# Epoch [5/15], Iter [80,430] Loss:0.5058, average_loss: 0.5494
# Epoch [5/15], Iter [90,430] Loss:0.5138, average_loss: 0.5423
# Epoch [5/15], Iter [100,430] Loss:0.3551, average_loss: 0.5434
# Epoch [5/15], Iter [110,430] Loss:0.5733, average_loss: 0.5360
# Epoch [5/15], Iter [120,430] Loss:0.6892, average_loss: 0.5431
# Epoch [5/15], Iter [130,430] Loss:0.3460, average_loss: 0.5399
# Epoch [5/15], Iter [140,430] Loss:0.3681, average_loss: 0.5428
# Epoch [5/15], Iter [150,430] Loss:0.2567, average_loss: 0.5439
# Epoch [5/15], Iter [160,430] Loss:0.8079, average_loss: 0.5433
# Epoch [5/15], Iter [170,430] Loss:0.7203, average_loss: 0.5483
# Epoch [5/15], Iter [180,430] Loss:0.4913, average_loss: 0.5461
# Epoch [5/15], Iter [190,430] Loss:0.3343, average_loss: 0.5456
# Epoch [5/15], Iter [200,430] Loss:0.7817, average_loss: 0.5521
# Epoch [5/15], Iter [210,430] Loss:0.3790, average_loss: 0.5521
# Epoch [5/15], Iter [220,430] Loss:0.5540, average_loss: 0.5512
# Epoch [5/15], Iter [230,430] Loss:0.5116, average_loss: 0.5478
# Epoch [5/15], Iter [240,430] Loss:0.9218, average_loss: 0.5485
# Epoch [5/15], Iter [250,430] Loss:0.4870, average_loss: 0.5508
# Epoch [5/15], Iter [260,430] Loss:0.5313, average_loss: 0.5503
# Epoch [5/15], Iter [270,430] Loss:0.6217, average_loss: 0.5533
# Epoch [5/15], Iter [280,430] Loss:1.0036, average_loss: 0.5536
# Epoch [5/15], Iter [290,430] Loss:0.4706, average_loss: 0.5525
# Epoch [5/15], Iter [300,430] Loss:0.4685, average_loss: 0.5539
# Epoch [5/15], Iter [310,430] Loss:0.4575, average_loss: 0.5560
# Epoch [5/15], Iter [320,430] Loss:0.5901, average_loss: 0.5547
# Epoch [5/15], Iter [330,430] Loss:0.4110, average_loss: 0.5550
# Epoch [5/15], Iter [340,430] Loss:1.0280, average_loss: 0.5584
# Epoch [5/15], Iter [350,430] Loss:0.6361, average_loss: 0.5555
# Epoch [5/15], Iter [360,430] Loss:0.7697, average_loss: 0.5539
# Epoch [5/15], Iter [370,430] Loss:0.5440, average_loss: 0.5508
# Epoch [5/15], Iter [380,430] Loss:0.4803, average_loss: 0.5523
# Epoch [5/15], Iter [390,430] Loss:1.0360, average_loss: 0.5534
# Epoch [5/15], Iter [400,430] Loss:0.4316, average_loss: 0.5509
# Epoch [5/15], Iter [410,430] Loss:0.2514, average_loss: 0.5505
# Epoch [5/15], Iter [420,430] Loss:0.3257, average_loss: 0.5501
# Epoch [5/15], Iter [430,430] Loss:0.4101, average_loss: 0.5480
# Epoch [6/15], Iter [10,430] Loss:0.3946, average_loss: 0.6156
# Epoch [6/15], Iter [20,430] Loss:0.6784, average_loss: 0.5766
# Epoch [6/15], Iter [30,430] Loss:0.2606, average_loss: 0.5258
# Epoch [6/15], Iter [40,430] Loss:0.4312, average_loss: 0.5154
# Epoch [6/15], Iter [50,430] Loss:0.3031, average_loss: 0.5106
# Epoch [6/15], Iter [60,430] Loss:0.3210, average_loss: 0.5206
# Epoch [6/15], Iter [70,430] Loss:0.2638, average_loss: 0.5091
# Epoch [6/15], Iter [80,430] Loss:1.1757, average_loss: 0.5299
# Epoch [6/15], Iter [90,430] Loss:0.5498, average_loss: 0.5236
# Epoch [6/15], Iter [100,430] Loss:0.3503, average_loss: 0.5270
# Epoch [6/15], Iter [110,430] Loss:0.3244, average_loss: 0.5271
# Epoch [6/15], Iter [120,430] Loss:0.5630, average_loss: 0.5319
# Epoch [6/15], Iter [130,430] Loss:0.5484, average_loss: 0.5272
# Epoch [6/15], Iter [140,430] Loss:0.3854, average_loss: 0.5278
# Epoch [6/15], Iter [150,430] Loss:0.4714, average_loss: 0.5257
# Epoch [6/15], Iter [160,430] Loss:0.5745, average_loss: 0.5262
# Epoch [6/15], Iter [170,430] Loss:0.6421, average_loss: 0.5284
# Epoch [6/15], Iter [180,430] Loss:0.7144, average_loss: 0.5341
# Epoch [6/15], Iter [190,430] Loss:1.2642, average_loss: 0.5417
# Epoch [6/15], Iter [200,430] Loss:0.4407, average_loss: 0.5412
# Epoch [6/15], Iter [210,430] Loss:0.6877, average_loss: 0.5390
# Epoch [6/15], Iter [220,430] Loss:0.3489, average_loss: 0.5349
# Epoch [6/15], Iter [230,430] Loss:0.7388, average_loss: 0.5368
# Epoch [6/15], Iter [240,430] Loss:0.3322, average_loss: 0.5377
# Epoch [6/15], Iter [250,430] Loss:0.2103, average_loss: 0.5405
# Epoch [6/15], Iter [260,430] Loss:0.2920, average_loss: 0.5411
# Epoch [6/15], Iter [270,430] Loss:0.4132, average_loss: 0.5394
# Epoch [6/15], Iter [280,430] Loss:0.3750, average_loss: 0.5366
# Epoch [6/15], Iter [290,430] Loss:0.3467, average_loss: 0.5376
# Epoch [6/15], Iter [300,430] Loss:0.5480, average_loss: 0.5387
# Epoch [6/15], Iter [310,430] Loss:0.6524, average_loss: 0.5381
# Epoch [6/15], Iter [320,430] Loss:0.4550, average_loss: 0.5404
# Epoch [6/15], Iter [330,430] Loss:0.4345, average_loss: 0.5376
# Epoch [6/15], Iter [340,430] Loss:0.3503, average_loss: 0.5356
# Epoch [6/15], Iter [350,430] Loss:0.9042, average_loss: 0.5357
# Epoch [6/15], Iter [360,430] Loss:0.5761, average_loss: 0.5347
# Epoch [6/15], Iter [370,430] Loss:0.7683, average_loss: 0.5363
# Epoch [6/15], Iter [380,430] Loss:0.3780, average_loss: 0.5349
# Epoch [6/15], Iter [390,430] Loss:0.5880, average_loss: 0.5369
# Epoch [6/15], Iter [400,430] Loss:0.4013, average_loss: 0.5372
# Epoch [6/15], Iter [410,430] Loss:0.5305, average_loss: 0.5382
# Epoch [6/15], Iter [420,430] Loss:0.3498, average_loss: 0.5380
# Epoch [6/15], Iter [430,430] Loss:0.5074, average_loss: 0.5402
# Epoch [7/15], Iter [10,430] Loss:0.6448, average_loss: 0.5086
# Epoch [7/15], Iter [20,430] Loss:0.8075, average_loss: 0.5543
# Epoch [7/15], Iter [30,430] Loss:0.4490, average_loss: 0.4934
# Epoch [7/15], Iter [40,430] Loss:0.5502, average_loss: 0.4945
# Epoch [7/15], Iter [50,430] Loss:0.3830, average_loss: 0.5002
# Epoch [7/15], Iter [60,430] Loss:0.5285, average_loss: 0.4975
# Epoch [7/15], Iter [70,430] Loss:0.4467, average_loss: 0.4933
# Epoch [7/15], Iter [80,430] Loss:1.1140, average_loss: 0.4911
# Epoch [7/15], Iter [90,430] Loss:0.3809, average_loss: 0.4849
# Epoch [7/15], Iter [100,430] Loss:0.5659, average_loss: 0.4963
# Epoch [7/15], Iter [110,430] Loss:0.2345, average_loss: 0.4976
# Epoch [7/15], Iter [120,430] Loss:0.4786, average_loss: 0.4979
# Epoch [7/15], Iter [130,430] Loss:0.4452, average_loss: 0.4962
# Epoch [7/15], Iter [140,430] Loss:0.6636, average_loss: 0.5007
# Epoch [7/15], Iter [150,430] Loss:0.7184, average_loss: 0.5027
# Epoch [7/15], Iter [160,430] Loss:0.6409, average_loss: 0.5083
# Epoch [7/15], Iter [170,430] Loss:0.3911, average_loss: 0.5037
# Epoch [7/15], Iter [180,430] Loss:0.5569, average_loss: 0.5064
# Epoch [7/15], Iter [190,430] Loss:0.7202, average_loss: 0.5086
# Epoch [7/15], Iter [200,430] Loss:0.5563, average_loss: 0.5213
# Epoch [7/15], Iter [210,430] Loss:0.8177, average_loss: 0.5215
# Epoch [7/15], Iter [220,430] Loss:0.5680, average_loss: 0.5181
# Epoch [7/15], Iter [230,430] Loss:0.5005, average_loss: 0.5197
# Epoch [7/15], Iter [240,430] Loss:0.7622, average_loss: 0.5193
# Epoch [7/15], Iter [250,430] Loss:0.8936, average_loss: 0.5239
# Epoch [7/15], Iter [260,430] Loss:0.9108, average_loss: 0.5298
# Epoch [7/15], Iter [270,430] Loss:0.4947, average_loss: 0.5281
# Epoch [7/15], Iter [280,430] Loss:0.9461, average_loss: 0.5316
# Epoch [7/15], Iter [290,430] Loss:0.8276, average_loss: 0.5348
# Epoch [7/15], Iter [300,430] Loss:0.6765, average_loss: 0.5336
# Epoch [7/15], Iter [310,430] Loss:0.7035, average_loss: 0.5314
# Epoch [7/15], Iter [320,430] Loss:0.8555, average_loss: 0.5351
# Epoch [7/15], Iter [330,430] Loss:0.2918, average_loss: 0.5333
# Epoch [7/15], Iter [340,430] Loss:0.3260, average_loss: 0.5357
# Epoch [7/15], Iter [350,430] Loss:0.6767, average_loss: 0.5347
# Epoch [7/15], Iter [360,430] Loss:0.3439, average_loss: 0.5367
# Epoch [7/15], Iter [370,430] Loss:0.3679, average_loss: 0.5346
# Epoch [7/15], Iter [380,430] Loss:0.4397, average_loss: 0.5371
# Epoch [7/15], Iter [390,430] Loss:0.5012, average_loss: 0.5347
# Epoch [7/15], Iter [400,430] Loss:0.5400, average_loss: 0.5372
# Epoch [7/15], Iter [410,430] Loss:0.3208, average_loss: 0.5343
# Epoch [7/15], Iter [420,430] Loss:0.3733, average_loss: 0.5345
# Epoch [7/15], Iter [430,430] Loss:0.4868, average_loss: 0.5359
# Epoch [8/15], Iter [10,430] Loss:0.5765, average_loss: 0.5079
# Epoch [8/15], Iter [20,430] Loss:0.6140, average_loss: 0.5200
# Epoch [8/15], Iter [30,430] Loss:0.5035, average_loss: 0.5272
# Epoch [8/15], Iter [40,430] Loss:0.6643, average_loss: 0.5049
# Epoch [8/15], Iter [50,430] Loss:0.6478, average_loss: 0.4949
# Epoch [8/15], Iter [60,430] Loss:0.2847, average_loss: 0.4976
# Epoch [8/15], Iter [70,430] Loss:0.4490, average_loss: 0.4890
# Epoch [8/15], Iter [80,430] Loss:0.5648, average_loss: 0.4845
# Epoch [8/15], Iter [90,430] Loss:0.4969, average_loss: 0.4961
# Epoch [8/15], Iter [100,430] Loss:1.4690, average_loss: 0.4992
# Epoch [8/15], Iter [110,430] Loss:0.3728, average_loss: 0.4981
# Epoch [8/15], Iter [120,430] Loss:0.3781, average_loss: 0.4968
# Epoch [8/15], Iter [130,430] Loss:0.8186, average_loss: 0.5001
# Epoch [8/15], Iter [140,430] Loss:0.4462, average_loss: 0.5006
# Epoch [8/15], Iter [150,430] Loss:0.3344, average_loss: 0.5058
# Epoch [8/15], Iter [160,430] Loss:0.3973, average_loss: 0.5061
# Epoch [8/15], Iter [170,430] Loss:0.8339, average_loss: 0.5076
# Epoch [8/15], Iter [180,430] Loss:0.2904, average_loss: 0.5104
# Epoch [8/15], Iter [190,430] Loss:0.4445, average_loss: 0.5101
# Epoch [8/15], Iter [200,430] Loss:0.5831, average_loss: 0.5122
# Epoch [8/15], Iter [210,430] Loss:0.5546, average_loss: 0.5135
# Epoch [8/15], Iter [220,430] Loss:0.6600, average_loss: 0.5171
# Epoch [8/15], Iter [230,430] Loss:0.4493, average_loss: 0.5139
# Epoch [8/15], Iter [240,430] Loss:0.4561, average_loss: 0.5125
# Epoch [8/15], Iter [250,430] Loss:0.5168, average_loss: 0.5185
# Epoch [8/15], Iter [260,430] Loss:0.2808, average_loss: 0.5218
# Epoch [8/15], Iter [270,430] Loss:0.5907, average_loss: 0.5226
# Epoch [8/15], Iter [280,430] Loss:0.2727, average_loss: 0.5254
# Epoch [8/15], Iter [290,430] Loss:0.4743, average_loss: 0.5270
# Epoch [8/15], Iter [300,430] Loss:0.3517, average_loss: 0.5235
# Epoch [8/15], Iter [310,430] Loss:0.3684, average_loss: 0.5270
# Epoch [8/15], Iter [320,430] Loss:0.3105, average_loss: 0.5259
# Epoch [8/15], Iter [330,430] Loss:0.2242, average_loss: 0.5272
# Epoch [8/15], Iter [340,430] Loss:0.6146, average_loss: 0.5287
# Epoch [8/15], Iter [350,430] Loss:0.4229, average_loss: 0.5284
# Epoch [8/15], Iter [360,430] Loss:0.3841, average_loss: 0.5281
# Epoch [8/15], Iter [370,430] Loss:1.0809, average_loss: 0.5299
# Epoch [8/15], Iter [380,430] Loss:0.7125, average_loss: 0.5287
# Epoch [8/15], Iter [390,430] Loss:0.4726, average_loss: 0.5259
# Epoch [8/15], Iter [400,430] Loss:0.3519, average_loss: 0.5253
# Epoch [8/15], Iter [410,430] Loss:0.5713, average_loss: 0.5280
# Epoch [8/15], Iter [420,430] Loss:0.4571, average_loss: 0.5250
# Epoch [8/15], Iter [430,430] Loss:0.4349, average_loss: 0.5231
# Epoch [9/15], Iter [10,430] Loss:0.5175, average_loss: 0.5511
# Epoch [9/15], Iter [20,430] Loss:0.3223, average_loss: 0.5619
# Epoch [9/15], Iter [30,430] Loss:0.4707, average_loss: 0.5163
# Epoch [9/15], Iter [40,430] Loss:0.2848, average_loss: 0.5256
# Epoch [9/15], Iter [50,430] Loss:0.5332, average_loss: 0.5364
# Epoch [9/15], Iter [60,430] Loss:0.6533, average_loss: 0.5374
# Epoch [9/15], Iter [70,430] Loss:0.4185, average_loss: 0.5459
# Epoch [9/15], Iter [80,430] Loss:0.1975, average_loss: 0.5333
# Epoch [9/15], Iter [90,430] Loss:0.7156, average_loss: 0.5286
# Epoch [9/15], Iter [100,430] Loss:1.1123, average_loss: 0.5477
# Epoch [9/15], Iter [110,430] Loss:0.3787, average_loss: 0.5468
# Epoch [9/15], Iter [120,430] Loss:0.3375, average_loss: 0.5451
# Epoch [9/15], Iter [130,430] Loss:0.5871, average_loss: 0.5386
# Epoch [9/15], Iter [140,430] Loss:0.4231, average_loss: 0.5297
# Epoch [9/15], Iter [150,430] Loss:0.3355, average_loss: 0.5274
# Epoch [9/15], Iter [160,430] Loss:0.8057, average_loss: 0.5270
# Epoch [9/15], Iter [170,430] Loss:1.0484, average_loss: 0.5332
# Epoch [9/15], Iter [180,430] Loss:0.4870, average_loss: 0.5279
# Epoch [9/15], Iter [190,430] Loss:0.7867, average_loss: 0.5313
# Epoch [9/15], Iter [200,430] Loss:0.3068, average_loss: 0.5280
# Epoch [9/15], Iter [210,430] Loss:0.3434, average_loss: 0.5243
# Epoch [9/15], Iter [220,430] Loss:0.7500, average_loss: 0.5242
# Epoch [9/15], Iter [230,430] Loss:0.5594, average_loss: 0.5220
# Epoch [9/15], Iter [240,430] Loss:0.3582, average_loss: 0.5194
# Epoch [9/15], Iter [250,430] Loss:0.7268, average_loss: 0.5247
# Epoch [9/15], Iter [260,430] Loss:0.5570, average_loss: 0.5228
# Epoch [9/15], Iter [270,430] Loss:0.5066, average_loss: 0.5215
# Epoch [9/15], Iter [280,430] Loss:0.5851, average_loss: 0.5221
# Epoch [9/15], Iter [290,430] Loss:0.3380, average_loss: 0.5220
# Epoch [9/15], Iter [300,430] Loss:0.4462, average_loss: 0.5220
# Epoch [9/15], Iter [310,430] Loss:0.5626, average_loss: 0.5239
# Epoch [9/15], Iter [320,430] Loss:0.8775, average_loss: 0.5253
# Epoch [9/15], Iter [330,430] Loss:0.5646, average_loss: 0.5260
# Epoch [9/15], Iter [340,430] Loss:0.3083, average_loss: 0.5259
# Epoch [9/15], Iter [350,430] Loss:0.3858, average_loss: 0.5241
# Epoch [9/15], Iter [360,430] Loss:0.7041, average_loss: 0.5243
# Epoch [9/15], Iter [370,430] Loss:0.5340, average_loss: 0.5250
# Epoch [9/15], Iter [380,430] Loss:0.2968, average_loss: 0.5235
# Epoch [9/15], Iter [390,430] Loss:0.5051, average_loss: 0.5243
# Epoch [9/15], Iter [400,430] Loss:0.6525, average_loss: 0.5251
# Epoch [9/15], Iter [410,430] Loss:0.4597, average_loss: 0.5237
# Epoch [9/15], Iter [420,430] Loss:0.7104, average_loss: 0.5235
# Epoch [9/15], Iter [430,430] Loss:0.6543, average_loss: 0.5262
# Epoch [10/15], Iter [10,430] Loss:0.4310, average_loss: 0.4074
# Epoch [10/15], Iter [20,430] Loss:0.3953, average_loss: 0.4327
# Epoch [10/15], Iter [30,430] Loss:0.8967, average_loss: 0.4799
# Epoch [10/15], Iter [40,430] Loss:0.2867, average_loss: 0.4770
# Epoch [10/15], Iter [50,430] Loss:0.6044, average_loss: 0.4940
# Epoch [10/15], Iter [60,430] Loss:0.2870, average_loss: 0.4975
# Epoch [10/15], Iter [70,430] Loss:0.8935, average_loss: 0.5144
# Epoch [10/15], Iter [80,430] Loss:0.4158, average_loss: 0.5183
# Epoch [10/15], Iter [90,430] Loss:0.9393, average_loss: 0.5322
# Epoch [10/15], Iter [100,430] Loss:0.3639, average_loss: 0.5356
# Epoch [10/15], Iter [110,430] Loss:0.5653, average_loss: 0.5343
# Epoch [10/15], Iter [120,430] Loss:0.4013, average_loss: 0.5345
# Epoch [10/15], Iter [130,430] Loss:0.3194, average_loss: 0.5322
# Epoch [10/15], Iter [140,430] Loss:0.5621, average_loss: 0.5315
# Epoch [10/15], Iter [150,430] Loss:0.7765, average_loss: 0.5303
# Epoch [10/15], Iter [160,430] Loss:0.4680, average_loss: 0.5263
# Epoch [10/15], Iter [170,430] Loss:0.5989, average_loss: 0.5253
# Epoch [10/15], Iter [180,430] Loss:0.3371, average_loss: 0.5194
# Epoch [10/15], Iter [190,430] Loss:0.4484, average_loss: 0.5163
# Epoch [10/15], Iter [200,430] Loss:0.2700, average_loss: 0.5112
# Epoch [10/15], Iter [210,430] Loss:0.6206, average_loss: 0.5128
# Epoch [10/15], Iter [220,430] Loss:0.8656, average_loss: 0.5207
# Epoch [10/15], Iter [230,430] Loss:0.2875, average_loss: 0.5200
# Epoch [10/15], Iter [240,430] Loss:0.8009, average_loss: 0.5179
# Epoch [10/15], Iter [250,430] Loss:0.4882, average_loss: 0.5174
# Epoch [10/15], Iter [260,430] Loss:0.5201, average_loss: 0.5235
# Epoch [10/15], Iter [270,430] Loss:0.8139, average_loss: 0.5205
# Epoch [10/15], Iter [280,430] Loss:0.3476, average_loss: 0.5213
# Epoch [10/15], Iter [290,430] Loss:0.4166, average_loss: 0.5221
# Epoch [10/15], Iter [300,430] Loss:0.8661, average_loss: 0.5224
# Epoch [10/15], Iter [310,430] Loss:0.6076, average_loss: 0.5215
# Epoch [10/15], Iter [320,430] Loss:0.3582, average_loss: 0.5212
# Epoch [10/15], Iter [330,430] Loss:0.4981, average_loss: 0.5205
# Epoch [10/15], Iter [340,430] Loss:0.5283, average_loss: 0.5227
# Epoch [10/15], Iter [350,430] Loss:0.4548, average_loss: 0.5214
# Epoch [10/15], Iter [360,430] Loss:0.5231, average_loss: 0.5227
# Epoch [10/15], Iter [370,430] Loss:1.9092, average_loss: 0.5242
# Epoch [10/15], Iter [380,430] Loss:0.5458, average_loss: 0.5261
# Epoch [10/15], Iter [390,430] Loss:0.5344, average_loss: 0.5278
# Epoch [10/15], Iter [400,430] Loss:0.2114, average_loss: 0.5251
# Epoch [10/15], Iter [410,430] Loss:0.5404, average_loss: 0.5244
# Epoch [10/15], Iter [420,430] Loss:0.6816, average_loss: 0.5231
# Epoch [10/15], Iter [430,430] Loss:0.4943, average_loss: 0.5244
# Epoch [11/15], Iter [10,430] Loss:0.5037, average_loss: 0.5180
# Epoch [11/15], Iter [20,430] Loss:0.9522, average_loss: 0.4993
# Epoch [11/15], Iter [30,430] Loss:0.4946, average_loss: 0.5347
# Epoch [11/15], Iter [40,430] Loss:0.5521, average_loss: 0.5455
# Epoch [11/15], Iter [50,430] Loss:0.8237, average_loss: 0.5454
# Epoch [11/15], Iter [60,430] Loss:0.4927, average_loss: 0.5295
# Epoch [11/15], Iter [70,430] Loss:0.4466, average_loss: 0.5286
# Epoch [11/15], Iter [80,430] Loss:0.2652, average_loss: 0.5368
# Epoch [11/15], Iter [90,430] Loss:1.2276, average_loss: 0.5282
# Epoch [11/15], Iter [100,430] Loss:0.3443, average_loss: 0.5293
# Epoch [11/15], Iter [110,430] Loss:0.6953, average_loss: 0.5300
# Epoch [11/15], Iter [120,430] Loss:0.6832, average_loss: 0.5345
# Epoch [11/15], Iter [130,430] Loss:0.4659, average_loss: 0.5320
# Epoch [11/15], Iter [140,430] Loss:0.6414, average_loss: 0.5275
# Epoch [11/15], Iter [150,430] Loss:1.1124, average_loss: 0.5344
# Epoch [11/15], Iter [160,430] Loss:0.4997, average_loss: 0.5250
# Epoch [11/15], Iter [170,430] Loss:0.4361, average_loss: 0.5249
# Epoch [11/15], Iter [180,430] Loss:0.4650, average_loss: 0.5244
# Epoch [11/15], Iter [190,430] Loss:0.5297, average_loss: 0.5205
# Epoch [11/15], Iter [200,430] Loss:0.6453, average_loss: 0.5202
# Epoch [11/15], Iter [210,430] Loss:0.3330, average_loss: 0.5248
# Epoch [11/15], Iter [220,430] Loss:0.3813, average_loss: 0.5223
# Epoch [11/15], Iter [230,430] Loss:0.3857, average_loss: 0.5227
# Epoch [11/15], Iter [240,430] Loss:0.5060, average_loss: 0.5201
# Epoch [11/15], Iter [250,430] Loss:0.4126, average_loss: 0.5195
# Epoch [11/15], Iter [260,430] Loss:0.3962, average_loss: 0.5179
# Epoch [11/15], Iter [270,430] Loss:0.3742, average_loss: 0.5164
# Epoch [11/15], Iter [280,430] Loss:0.3094, average_loss: 0.5124
# Epoch [11/15], Iter [290,430] Loss:0.4379, average_loss: 0.5112
# Epoch [11/15], Iter [300,430] Loss:0.4661, average_loss: 0.5111
# Epoch [11/15], Iter [310,430] Loss:0.5141, average_loss: 0.5121
# Epoch [11/15], Iter [320,430] Loss:0.5048, average_loss: 0.5128
# Epoch [11/15], Iter [330,430] Loss:0.5779, average_loss: 0.5132
# Epoch [11/15], Iter [340,430] Loss:0.8901, average_loss: 0.5167
# Epoch [11/15], Iter [350,430] Loss:0.5642, average_loss: 0.5156
# Epoch [11/15], Iter [360,430] Loss:0.3739, average_loss: 0.5153
# Epoch [11/15], Iter [370,430] Loss:0.5002, average_loss: 0.5140
# Epoch [11/15], Iter [380,430] Loss:0.3692, average_loss: 0.5147
# Epoch [11/15], Iter [390,430] Loss:0.4605, average_loss: 0.5159
# Epoch [11/15], Iter [400,430] Loss:0.5382, average_loss: 0.5154
# Epoch [11/15], Iter [410,430] Loss:0.4101, average_loss: 0.5165
# Epoch [11/15], Iter [420,430] Loss:0.3709, average_loss: 0.5178
# Epoch [11/15], Iter [430,430] Loss:0.8321, average_loss: 0.5194
# Epoch [12/15], Iter [10,430] Loss:0.4500, average_loss: 0.5385
# Epoch [12/15], Iter [20,430] Loss:0.5773, average_loss: 0.5514
# Epoch [12/15], Iter [30,430] Loss:0.5525, average_loss: 0.5503
# Epoch [12/15], Iter [40,430] Loss:0.4316, average_loss: 0.5236
# Epoch [12/15], Iter [50,430] Loss:0.3426, average_loss: 0.5717
# Epoch [12/15], Iter [60,430] Loss:0.4063, average_loss: 0.5572
# Epoch [12/15], Iter [70,430] Loss:0.2749, average_loss: 0.5477
# Epoch [12/15], Iter [80,430] Loss:0.3044, average_loss: 0.5538
# Epoch [12/15], Iter [90,430] Loss:0.5389, average_loss: 0.5535
# Epoch [12/15], Iter [100,430] Loss:0.3509, average_loss: 0.5405
# Epoch [12/15], Iter [110,430] Loss:1.0314, average_loss: 0.5438
# Epoch [12/15], Iter [120,430] Loss:0.4602, average_loss: 0.5428
# Epoch [12/15], Iter [130,430] Loss:0.3812, average_loss: 0.5357
# Epoch [12/15], Iter [140,430] Loss:0.3818, average_loss: 0.5299
# Epoch [12/15], Iter [150,430] Loss:0.4134, average_loss: 0.5264
# Epoch [12/15], Iter [160,430] Loss:0.9262, average_loss: 0.5245
# Epoch [12/15], Iter [170,430] Loss:0.6528, average_loss: 0.5203
# Epoch [12/15], Iter [180,430] Loss:0.3197, average_loss: 0.5239
# Epoch [12/15], Iter [190,430] Loss:0.3833, average_loss: 0.5194
# Epoch [12/15], Iter [200,430] Loss:0.4895, average_loss: 0.5185
# Epoch [12/15], Iter [210,430] Loss:0.4540, average_loss: 0.5173
# Epoch [12/15], Iter [220,430] Loss:0.4804, average_loss: 0.5161
# Epoch [12/15], Iter [230,430] Loss:0.2832, average_loss: 0.5123
# Epoch [12/15], Iter [240,430] Loss:0.3215, average_loss: 0.5101
# Epoch [12/15], Iter [250,430] Loss:0.5855, average_loss: 0.5076
# Epoch [12/15], Iter [260,430] Loss:0.3852, average_loss: 0.5069
# Epoch [12/15], Iter [270,430] Loss:0.2207, average_loss: 0.5072
# Epoch [12/15], Iter [280,430] Loss:0.9660, average_loss: 0.5150
# Epoch [12/15], Iter [290,430] Loss:0.4903, average_loss: 0.5179
# Epoch [12/15], Iter [300,430] Loss:0.3059, average_loss: 0.5175
# Epoch [12/15], Iter [310,430] Loss:0.5882, average_loss: 0.5247
# Epoch [12/15], Iter [320,430] Loss:0.5987, average_loss: 0.5222
# Epoch [12/15], Iter [330,430] Loss:0.9044, average_loss: 0.5246
# Epoch [12/15], Iter [340,430] Loss:1.0879, average_loss: 0.5303
# Epoch [12/15], Iter [350,430] Loss:0.3110, average_loss: 0.5293
# Epoch [12/15], Iter [360,430] Loss:0.4006, average_loss: 0.5283
# Epoch [12/15], Iter [370,430] Loss:0.8330, average_loss: 0.5282
# Epoch [12/15], Iter [380,430] Loss:0.8677, average_loss: 0.5302
# Epoch [12/15], Iter [390,430] Loss:0.6857, average_loss: 0.5310
# Epoch [12/15], Iter [400,430] Loss:0.3718, average_loss: 0.5297
# Epoch [12/15], Iter [410,430] Loss:0.3259, average_loss: 0.5323
# Epoch [12/15], Iter [420,430] Loss:0.9410, average_loss: 0.5326
# Epoch [12/15], Iter [430,430] Loss:0.3656, average_loss: 0.5325
# Epoch [13/15], Iter [10,430] Loss:0.5611, average_loss: 0.4693
# Epoch [13/15], Iter [20,430] Loss:0.6816, average_loss: 0.5155
# Epoch [13/15], Iter [30,430] Loss:0.5315, average_loss: 0.4993
# Epoch [13/15], Iter [40,430] Loss:0.4510, average_loss: 0.4945
# Epoch [13/15], Iter [50,430] Loss:0.2737, average_loss: 0.4867
# Epoch [13/15], Iter [60,430] Loss:0.2726, average_loss: 0.4982
# Epoch [13/15], Iter [70,430] Loss:0.3679, average_loss: 0.4828
# Epoch [13/15], Iter [80,430] Loss:0.6001, average_loss: 0.4835
# Epoch [13/15], Iter [90,430] Loss:0.3105, average_loss: 0.4930
# Epoch [13/15], Iter [100,430] Loss:0.4927, average_loss: 0.4972
# Epoch [13/15], Iter [110,430] Loss:0.7083, average_loss: 0.5003
# Epoch [13/15], Iter [120,430] Loss:0.3722, average_loss: 0.5019
# Epoch [13/15], Iter [130,430] Loss:0.3467, average_loss: 0.5004
# Epoch [13/15], Iter [140,430] Loss:0.4068, average_loss: 0.5065
# Epoch [13/15], Iter [150,430] Loss:0.4500, average_loss: 0.5078
# Epoch [13/15], Iter [160,430] Loss:0.2000, average_loss: 0.5103
# Epoch [13/15], Iter [170,430] Loss:0.9670, average_loss: 0.5172
# Epoch [13/15], Iter [180,430] Loss:0.4588, average_loss: 0.5144
# Epoch [13/15], Iter [190,430] Loss:0.2733, average_loss: 0.5158
# Epoch [13/15], Iter [200,430] Loss:0.3428, average_loss: 0.5133
# Epoch [13/15], Iter [210,430] Loss:0.5350, average_loss: 0.5154
# Epoch [13/15], Iter [220,430] Loss:1.1470, average_loss: 0.5206
# Epoch [13/15], Iter [230,430] Loss:0.4465, average_loss: 0.5194
# Epoch [13/15], Iter [240,430] Loss:0.2908, average_loss: 0.5179
# Epoch [13/15], Iter [250,430] Loss:0.9196, average_loss: 0.5183
# Epoch [13/15], Iter [260,430] Loss:0.3753, average_loss: 0.5183
# Epoch [13/15], Iter [270,430] Loss:0.4647, average_loss: 0.5178
# Epoch [13/15], Iter [280,430] Loss:0.3017, average_loss: 0.5173
# Epoch [13/15], Iter [290,430] Loss:0.4529, average_loss: 0.5165
# Epoch [13/15], Iter [300,430] Loss:0.5525, average_loss: 0.5160
# Epoch [13/15], Iter [310,430] Loss:0.4431, average_loss: 0.5157
# Epoch [13/15], Iter [320,430] Loss:0.5040, average_loss: 0.5168
# Epoch [13/15], Iter [330,430] Loss:0.2980, average_loss: 0.5171
# Epoch [13/15], Iter [340,430] Loss:0.2507, average_loss: 0.5170
# Epoch [13/15], Iter [350,430] Loss:0.7886, average_loss: 0.5182
# Epoch [13/15], Iter [360,430] Loss:0.3191, average_loss: 0.5164
# Epoch [13/15], Iter [370,430] Loss:0.5156, average_loss: 0.5164
# Epoch [13/15], Iter [380,430] Loss:0.9673, average_loss: 0.5182
# Epoch [13/15], Iter [390,430] Loss:0.6956, average_loss: 0.5204
# Epoch [13/15], Iter [400,430] Loss:0.5085, average_loss: 0.5211
# Epoch [13/15], Iter [410,430] Loss:0.4025, average_loss: 0.5202
# Epoch [13/15], Iter [420,430] Loss:0.6420, average_loss: 0.5207
# Epoch [13/15], Iter [430,430] Loss:0.7762, average_loss: 0.5192
# Epoch [14/15], Iter [10,430] Loss:0.4498, average_loss: 0.4827
# Epoch [14/15], Iter [20,430] Loss:0.4088, average_loss: 0.5100
# Epoch [14/15], Iter [30,430] Loss:0.4677, average_loss: 0.5056
# Epoch [14/15], Iter [40,430] Loss:0.4555, average_loss: 0.4782
# Epoch [14/15], Iter [50,430] Loss:0.4101, average_loss: 0.4774
# Epoch [14/15], Iter [60,430] Loss:0.6287, average_loss: 0.4935
# Epoch [14/15], Iter [70,430] Loss:0.4294, average_loss: 0.4918
# Epoch [14/15], Iter [80,430] Loss:0.4415, average_loss: 0.4951
# Epoch [14/15], Iter [90,430] Loss:0.2690, average_loss: 0.4923
# Epoch [14/15], Iter [100,430] Loss:0.5476, average_loss: 0.4972
# Epoch [14/15], Iter [110,430] Loss:0.4396, average_loss: 0.5012
# Epoch [14/15], Iter [120,430] Loss:0.3818, average_loss: 0.4959
# Epoch [14/15], Iter [130,430] Loss:0.3590, average_loss: 0.4925
# Epoch [14/15], Iter [140,430] Loss:0.4579, average_loss: 0.4919
# Epoch [14/15], Iter [150,430] Loss:0.7197, average_loss: 0.4960
# Epoch [14/15], Iter [160,430] Loss:0.4943, average_loss: 0.4939
# Epoch [14/15], Iter [170,430] Loss:0.2997, average_loss: 0.4903
# Epoch [14/15], Iter [180,430] Loss:0.4027, average_loss: 0.4879
# Epoch [14/15], Iter [190,430] Loss:0.3373, average_loss: 0.4904
# Epoch [14/15], Iter [200,430] Loss:0.5871, average_loss: 0.4927
# Epoch [14/15], Iter [210,430] Loss:0.3651, average_loss: 0.4948
# Epoch [14/15], Iter [220,430] Loss:0.3333, average_loss: 0.4937
# Epoch [14/15], Iter [230,430] Loss:0.4788, average_loss: 0.4986
# Epoch [14/15], Iter [240,430] Loss:0.4892, average_loss: 0.5019
# Epoch [14/15], Iter [250,430] Loss:0.6392, average_loss: 0.5056
# Epoch [14/15], Iter [260,430] Loss:0.7305, average_loss: 0.5099
# Epoch [14/15], Iter [270,430] Loss:0.3887, average_loss: 0.5113
# Epoch [14/15], Iter [280,430] Loss:0.4607, average_loss: 0.5118
# Epoch [14/15], Iter [290,430] Loss:0.4631, average_loss: 0.5088
# Epoch [14/15], Iter [300,430] Loss:0.4033, average_loss: 0.5089
# Epoch [14/15], Iter [310,430] Loss:0.4151, average_loss: 0.5070
# Epoch [14/15], Iter [320,430] Loss:0.4385, average_loss: 0.5074
# Epoch [14/15], Iter [330,430] Loss:0.3783, average_loss: 0.5069
# Epoch [14/15], Iter [340,430] Loss:0.2756, average_loss: 0.5044
# Epoch [14/15], Iter [350,430] Loss:0.2719, average_loss: 0.5031
# Epoch [14/15], Iter [360,430] Loss:0.7249, average_loss: 0.5028
# Epoch [14/15], Iter [370,430] Loss:0.5914, average_loss: 0.5066
# Epoch [14/15], Iter [380,430] Loss:0.3034, average_loss: 0.5081
# Epoch [14/15], Iter [390,430] Loss:0.5266, average_loss: 0.5089
# Epoch [14/15], Iter [400,430] Loss:0.4003, average_loss: 0.5084
# Epoch [14/15], Iter [410,430] Loss:0.6294, average_loss: 0.5087
# Epoch [14/15], Iter [420,430] Loss:0.7114, average_loss: 0.5075
# Epoch [14/15], Iter [430,430] Loss:0.6750, average_loss: 0.5104
# Epoch [15/15], Iter [10,430] Loss:0.4878, average_loss: 0.4504
# Epoch [15/15], Iter [20,430] Loss:0.5981, average_loss: 0.4627
# Epoch [15/15], Iter [30,430] Loss:0.5594, average_loss: 0.5020
# Epoch [15/15], Iter [40,430] Loss:0.3499, average_loss: 0.5147
# Epoch [15/15], Iter [50,430] Loss:0.5625, average_loss: 0.5336
# Epoch [15/15], Iter [60,430] Loss:0.6286, average_loss: 0.5270
# Epoch [15/15], Iter [70,430] Loss:0.6898, average_loss: 0.5176
# Epoch [15/15], Iter [80,430] Loss:0.2197, average_loss: 0.5224
# Epoch [15/15], Iter [90,430] Loss:0.5001, average_loss: 0.5250
# Epoch [15/15], Iter [100,430] Loss:0.6939, average_loss: 0.5246
# Epoch [15/15], Iter [110,430] Loss:0.3938, average_loss: 0.5245
# Epoch [15/15], Iter [120,430] Loss:0.3819, average_loss: 0.5324
# Epoch [15/15], Iter [130,430] Loss:0.3980, average_loss: 0.5325
# Epoch [15/15], Iter [140,430] Loss:0.6373, average_loss: 0.5367
# Epoch [15/15], Iter [150,430] Loss:0.2466, average_loss: 0.5386
# Epoch [15/15], Iter [160,430] Loss:0.3855, average_loss: 0.5355
# Epoch [15/15], Iter [170,430] Loss:0.5676, average_loss: 0.5371
# Epoch [15/15], Iter [180,430] Loss:0.3698, average_loss: 0.5357
# Epoch [15/15], Iter [190,430] Loss:0.3442, average_loss: 0.5348
# Epoch [15/15], Iter [200,430] Loss:0.4790, average_loss: 0.5333
# Epoch [15/15], Iter [210,430] Loss:0.3216, average_loss: 0.5269
# Epoch [15/15], Iter [220,430] Loss:0.3750, average_loss: 0.5271
# Epoch [15/15], Iter [230,430] Loss:0.9383, average_loss: 0.5261
# Epoch [15/15], Iter [240,430] Loss:0.3281, average_loss: 0.5219
# Epoch [15/15], Iter [250,430] Loss:0.3687, average_loss: 0.5169
# Epoch [15/15], Iter [260,430] Loss:0.3384, average_loss: 0.5142
# Epoch [15/15], Iter [270,430] Loss:0.5118, average_loss: 0.5109
# Epoch [15/15], Iter [280,430] Loss:0.3221, average_loss: 0.5125
# Epoch [15/15], Iter [290,430] Loss:1.2157, average_loss: 0.5115
# Epoch [15/15], Iter [300,430] Loss:0.6134, average_loss: 0.5124
# Epoch [15/15], Iter [310,430] Loss:0.6562, average_loss: 0.5136
# Epoch [15/15], Iter [320,430] Loss:0.5166, average_loss: 0.5172
# Epoch [15/15], Iter [330,430] Loss:0.4587, average_loss: 0.5155
# Epoch [15/15], Iter [340,430] Loss:0.6575, average_loss: 0.5144
# Epoch [15/15], Iter [350,430] Loss:0.5123, average_loss: 0.5151
# Epoch [15/15], Iter [360,430] Loss:1.0962, average_loss: 0.5155
# Epoch [15/15], Iter [370,430] Loss:0.4306, average_loss: 0.5150
# Epoch [15/15], Iter [380,430] Loss:0.9891, average_loss: 0.5162
# Epoch [15/15], Iter [390,430] Loss:0.4653, average_loss: 0.5187
# Epoch [15/15], Iter [400,430] Loss:0.7996, average_loss: 0.5211
# Epoch [15/15], Iter [410,430] Loss:0.3598, average_loss: 0.5196
# Epoch [15/15], Iter [420,430] Loss:0.7065, average_loss: 0.5195
# Epoch [15/15], Iter [430,430] Loss:0.5094, average_loss: 0.5203

# %% [markdown]
# #### Step 5. Inference

# %% [markdown]
# ### Step 5-1. Inference (Visualizing)
# - The below code is for visualizing your results.
# - Check out!

# %%
## Visualizing the bouding box image
from misc.lab07.util import *

SMALL_VOC_CLASSES = ('aeroplane', 'bicycle', 'bus', 'car', 'cat', 'dog')

Color = [[0, 0, 0],
                    [128, 0, 0],
                    [0, 128, 0],
                    [128, 128, 0],
                    [0, 0, 128],
                    [128, 0, 128]]

def visualize(model, path):
    result = []
    image = cv2.imread(path)
    h, w, _ = image.shape
    img = cv2.resize(image, (448, 448))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    transform = transforms.Compose([transforms.ToTensor(),])
    img = 2 * transform(img) - 1
    img = Variable(img[None,:,:,:],volatile=True)
    img = img.cuda()
    
    pred = model(img) #1x7x7x30
    pred = pred.cpu()
    boxes,cls_indexs,probs =  interpret_target(pred, 0.1)
    
    for i, box in enumerate(boxes):
        
        x1 = max(int(box[0] * w), 0)
        x2 = min(int(box[2] * w), w)
        y1 = max(int(box[1] * h), 0)
        y2 = min(int(box[3] * h), h)
        cls_index = cls_indexs[i]
        cls_index = int(cls_index)
        prob = probs[i]
        prob = float(prob)
        result.append([(x1, y1), (x2, y2), SMALL_VOC_CLASSES[cls_index], prob])
        
    img = np.zeros((h, w, 3), np.bool)
    img = img + image[:,:,::-1]
        
    for left_up,right_bottom,class_name,prob in result:
        color = Color[SMALL_VOC_CLASSES.index(class_name)]
        cv2.rectangle(img, left_up, right_bottom, color, 2)
        label = class_name+str(round(prob,2))
        text_size, baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
        p1 = (left_up[0], left_up[1]- text_size[1])
        cv2.rectangle(img, (p1[0] - 2//2, p1[1] - 2 - baseline), (p1[0] + text_size[0], p1[1] + text_size[1]), color, -1)
        cv2.putText(img, label, (p1[0], p1[1] + baseline), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255,255,255), 1, 8)
    
    print(label)
    plt.imshow(img)
    
model.eval()
# Out:
# YOLO(
#   (pre_train_net): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): LeakyReLU(negative_slope=0.01)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1))
#     (7): LeakyReLU(negative_slope=0.01)
#     (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): LeakyReLU(negative_slope=0.01)
#     (10): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (11): LeakyReLU(negative_slope=0.01)
#     (12): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): LeakyReLU(negative_slope=0.01)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (16): LeakyReLU(negative_slope=0.01)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): LeakyReLU(negative_slope=0.01)
#     (19): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (20): LeakyReLU(negative_slope=0.01)
#     (21): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): LeakyReLU(negative_slope=0.01)
#     (23): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (24): LeakyReLU(negative_slope=0.01)
#     (25): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): LeakyReLU(negative_slope=0.01)
#     (27): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (28): LeakyReLU(negative_slope=0.01)
#     (29): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (30): LeakyReLU(negative_slope=0.01)
#     (31): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#     (32): LeakyReLU(negative_slope=0.01)
#     (33): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (34): LeakyReLU(negative_slope=0.01)
#     (35): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (36): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#     (37): LeakyReLU(negative_slope=0.01)
#     (38): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (39): LeakyReLU(negative_slope=0.01)
#   )
#   (post_net): Sequential(
#     (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): LeakyReLU(negative_slope=0.01)
#   )
#   (FC1): Sequential(
#     (0): Linear(in_features=50176, out_features=4096, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.5, inplace=False)
#   )
#   (FC2): Sequential(
#     (0): Linear(in_features=4096, out_features=1470, bias=True)
#   )
# )

# %% [markdown]
# ### Load the saved models

# %%
best_model = torch.load('./weights/lab07/best.pt')

# %%
epoch5_model = torch.load("./weights/lab07/epoch5.pt")

# %%
epoch10_model = torch.load("./weights/lab07/epoch10.pt")

# %%
epoch15_model = torch.load("./weights/lab07/epoch15.pt")

# %% [markdown]
# - You can check various results by chaning the name of files.

# %% [markdown]
# ### AP results of each model for randomly selected 10 images

# %%
import glob

img_list = glob.glob('./misc/lab07/Generate_dataset/images/*.jpg')

# %% [markdown]
# ### - Final model

# %%
img_list.sort()
flag = True
i = 0

for images in img_list:
    while flag:
        if int((images.split('/')[-1].split('.')[0])[2]) == i:
            visualize(model, images)
            i += 1
        else:
            break
# Out:
# cat0.35
# dog0.67
# cat0.68
# bus0.35
# dog0.41
# bicycle0.46
# car0.54
# car0.35
# car0.18
# bus0.44

# %% [markdown]
# ### - Best model

# %%
img_list.sort()
flag = True
i = 0

for images in img_list:
    while flag:
        if int((images.split('/')[-1].split('.')[0])[2]) == i:
            visualize(best_model, images)
            i += 1
        else:
            break
# Out:
# cat0.23
# dog0.8
# cat0.79
# aeroplane0.3
# dog0.28
# bicycle0.45
# car0.62
# car0.37
# car0.21
# bus0.45

# %% [markdown]
# ### - epoch5 model

# %%
img_list.sort()
flag = True
i = 0

for images in img_list:
    while flag:
        if int((images.split('/')[-1].split('.')[0])[2]) == i:
            visualize(epoch5_model, images)
            i += 1
        else:
            break
# Out:
# cat0.32
# dog0.94
# cat0.88
# bus0.18
# dog0.38
# bicycle0.32
# car0.51
# car0.55
# car0.15
# bus0.27

# %% [markdown]
# ### - epoch10 model

# %%
img_list.sort()
flag = True
i = 0

for images in img_list:
    while flag:
        if int((images.split('/')[-1].split('.')[0])[2]) == i:
            visualize(epoch10_model, images)
            i += 1
        else:
            break
# Out:
# cat0.19
# dog0.82
# cat0.8
# bus0.29
# dog0.32
# bicycle0.44
# car0.64
# car0.52
# car0.28
# bus0.31

# %% [markdown]
# ### - epoch15 model (= Final model)

# %%
img_list.sort()
flag = True
i = 0

for images in img_list:
    while flag:
        if int((images.split('/')[-1].split('.')[0])[2]) == i:
            visualize(epoch15_model, images)
            i += 1
        else:
            break
# Out:
# cat0.42
# dog0.73
# cat0.72
# bus0.42
# dog0.37
# bicycle0.42
# car0.56
# car0.37
# aeroplane0.11
# bus0.44

# %% [markdown]
# ### visualization of object detection result of final model(= epoch15 model)

# %%
visualize(model, './misc/lab07/Generate_dataset/images/004199.jpg')
# Out:
# aeroplane0.43

# %%
visualize(model, './misc/lab07/Generate_dataset/images/004477.jpg')
# Out:
# aeroplane0.13

# %%
visualize(model, './misc/lab07/Generate_dataset/images/005633.jpg')
# Out:
# aeroplane0.62

# %%
visualize(model, './misc/lab07/Generate_dataset/images/004377.jpg')
# Out:
# aeroplane0.0

# %%
visualize(model, './misc/lab07/Generate_dataset/images/006034.jpg')
# Out:
# car0.51

# %%
visualize(model, './misc/lab07/Generate_dataset/images/004337.jpg')
# Out:
# car0.1

# %% [markdown]
# ### visualization of object detection result of best model

# %%
visualize(best_model, './misc/lab07/Generate_dataset/images/004199.jpg')
# Out:
# aeroplane0.48

# %%
visualize(best_model, './misc/lab07/Generate_dataset/images/004477.jpg')
# Out:
# aeroplane0.19

# %%
visualize(best_model, './misc/lab07/Generate_dataset/images/005633.jpg')
# Out:
# aeroplane0.56

# %%
visualize(best_model, './misc/lab07/Generate_dataset/images/004377.jpg')
# Out:
# aeroplane0.0

# %%
visualize(best_model, './misc/lab07/Generate_dataset/images/006034.jpg')
# Out:
# car0.47

# %%
visualize(best_model, './misc/lab07/Generate_dataset/images/004337.jpg')
# Out:
# car0.11

# %% [markdown]
# ### Step 6-2. Inference (mAP)
# - The below code is for checkout your network performance,
# - By using this code, your network prediction is saved in Generate_dataset directory
# - Then, %run ./misc/lab07/Generate_dataset/main.py
# - After a few seconds, the mAP is printed.
# - **Note that if your code is correct, the mAP will be over 69.**

# %% [markdown]
# ### mAP result of Final Model(= epoch15 model)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

SMALL_VOC_CLASSES = ('aeroplane', 'bicycle', 'bus', 'car', 'cat', 'dog')
os.makedirs('predicted', exist_ok=True)

def write(model, path):
    result = []
    image = cv2.imread(path)
    h, w, _ = image.shape
    img = cv2.resize(image, (448, 448))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    transform = transforms.Compose([transforms.ToTensor(),])
    img = 2 * transform(img) - 1
    img = Variable(img[None,:,:,:],volatile=True)
    img = img.cuda()
    
    pred = model(img) #1x7x7x30
    pred = pred.cpu()
    boxes,cls_indexs,probs =  interpret_target(pred, 0)
    
    
    txt_file = open(os.path.join('predicted', os.path.basename(path)[:-4]+'.txt'), 'w')
    
    for i, box in enumerate(boxes):
        
        x1 = max(int(box[0] * w), 0)
        x2 = min(int(box[2] * w), w)
        y1 = max(int(box[1] * h), 0)
        y2 = min(int(box[3] * h), h)
        cls_index = cls_indexs[i]
        cls_index = int(cls_index)
        prob = probs[i]
        prob = float(prob)
        txt_file.write(str(SMALL_VOC_CLASSES[cls_index])+' '+'%.6f'%(prob)+' '+str(x1)+' '+str(y1)+' '+str(x2)+' '+str(y2))
        txt_file.write('\n')
    txt_file.close()
    
import glob

model.eval()
img_names = glob.glob('./misc/lab07/Generate_dataset/images/*')

for i, file_name in enumerate(img_names):
    write(model, file_name)
    if i % 500 == 0:
        print(i)
# Out:
# 0
# 500
# 1000

# %%
# %run ./misc/lab07/Generate_dataset/main.py
# Out:
# 65.59% = aeroplane AP
# 70.50% = bicycle AP
# 69.04% = bus AP
# 68.13% = car AP
# 76.64% = cat AP
# 76.07% = dog AP
# mAP = 71.00%

# %% [markdown]
# ### *References*
# [1] https://www.pyimagesearch.com/2018/05/14/a-gentle-guide-to-deep-learning-object-detection/
#
# [2] https://github.com/Cartucho/mAP

# %% [markdown]
# ### best model mAP

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

SMALL_VOC_CLASSES = ('aeroplane', 'bicycle', 'bus', 'car', 'cat', 'dog')
os.makedirs('predicted', exist_ok=True)

def write(model, path):
    result = []
    image = cv2.imread(path)
    h, w, _ = image.shape
    img = cv2.resize(image, (448, 448))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    transform = transforms.Compose([transforms.ToTensor(),])
    img = 2 * transform(img) - 1
    img = Variable(img[None,:,:,:],volatile=True)
    img = img.cuda()
    
    pred = model(img) #1x7x7x30
    pred = pred.cpu()
    boxes,cls_indexs,probs =  interpret_target(pred, 0)
    
    
    txt_file = open(os.path.join('predicted', os.path.basename(path)[:-4]+'.txt'), 'w')
    
    for i, box in enumerate(boxes):
        
        x1 = max(int(box[0] * w), 0)
        x2 = min(int(box[2] * w), w)
        y1 = max(int(box[1] * h), 0)
        y2 = min(int(box[3] * h), h)
        cls_index = cls_indexs[i]
        cls_index = int(cls_index)
        prob = probs[i]
        prob = float(prob)
        txt_file.write(str(SMALL_VOC_CLASSES[cls_index])+' '+'%.6f'%(prob)+' '+str(x1)+' '+str(y1)+' '+str(x2)+' '+str(y2))
        txt_file.write('\n')
    txt_file.close()
    
import glob

best_model.eval()
img_names = glob.glob('./misc/lab07/Generate_dataset/images/*')

for i, file_name in enumerate(img_names):
    write(best_model, file_name)
    if i % 500 == 0:
        print(i)
# Out:
# 0
# 500
# 1000

# %%
# %run ./misc/lab07/Generate_dataset/main.py
# Out:
# 66.23% = aeroplane AP
# 68.56% = bicycle AP
# 64.67% = bus AP
# 68.69% = car AP
# 76.26% = cat AP
# 76.09% = dog AP
# mAP = 70.08%

# %% [markdown]
# ### epoch5 model mAP

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

SMALL_VOC_CLASSES = ('aeroplane', 'bicycle', 'bus', 'car', 'cat', 'dog')
os.makedirs('predicted', exist_ok=True)

def write(model, path):
    result = []
    image = cv2.imread(path)
    h, w, _ = image.shape
    img = cv2.resize(image, (448, 448))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    transform = transforms.Compose([transforms.ToTensor(),])
    img = 2 * transform(img) - 1
    img = Variable(img[None,:,:,:],volatile=True)
    img = img.cuda()
    
    pred = model(img) #1x7x7x30
    pred = pred.cpu()
    boxes,cls_indexs,probs =  interpret_target(pred, 0)
    
    
    txt_file = open(os.path.join('predicted', os.path.basename(path)[:-4]+'.txt'), 'w')
    
    for i, box in enumerate(boxes):
        
        x1 = max(int(box[0] * w), 0)
        x2 = min(int(box[2] * w), w)
        y1 = max(int(box[1] * h), 0)
        y2 = min(int(box[3] * h), h)
        cls_index = cls_indexs[i]
        cls_index = int(cls_index)
        prob = probs[i]
        prob = float(prob)
        txt_file.write(str(SMALL_VOC_CLASSES[cls_index])+' '+'%.6f'%(prob)+' '+str(x1)+' '+str(y1)+' '+str(x2)+' '+str(y2))
        txt_file.write('\n')
    txt_file.close()
    
import glob

epoch5_model.eval()
img_names = glob.glob('./misc/lab07/Generate_dataset/images/*')

for i, file_name in enumerate(img_names):
    write(epoch5_model, file_name)
    if i % 500 == 0:
        print(i)
# Out:
# 0
# 500
# 1000

# %%
# %run ./misc/lab07/Generate_dataset/main.py
# Out:
# 65.63% = aeroplane AP
# 66.98% = bicycle AP
# 66.94% = bus AP
# 67.24% = car AP
# 73.52% = cat AP
# 75.12% = dog AP
# mAP = 69.24%

# %% [markdown]
# ### epoch10 model mAP

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

SMALL_VOC_CLASSES = ('aeroplane', 'bicycle', 'bus', 'car', 'cat', 'dog')
os.makedirs('predicted', exist_ok=True)

def write(model, path):
    result = []
    image = cv2.imread(path)
    h, w, _ = image.shape
    img = cv2.resize(image, (448, 448))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    transform = transforms.Compose([transforms.ToTensor(),])
    img = 2 * transform(img) - 1
    img = Variable(img[None,:,:,:],volatile=True)
    img = img.cuda()
    
    pred = model(img) #1x7x7x30
    pred = pred.cpu()
    boxes,cls_indexs,probs =  interpret_target(pred, 0)
    
    
    txt_file = open(os.path.join('predicted', os.path.basename(path)[:-4]+'.txt'), 'w')
    
    for i, box in enumerate(boxes):
        
        x1 = max(int(box[0] * w), 0)
        x2 = min(int(box[2] * w), w)
        y1 = max(int(box[1] * h), 0)
        y2 = min(int(box[3] * h), h)
        cls_index = cls_indexs[i]
        cls_index = int(cls_index)
        prob = probs[i]
        prob = float(prob)
        txt_file.write(str(SMALL_VOC_CLASSES[cls_index])+' '+'%.6f'%(prob)+' '+str(x1)+' '+str(y1)+' '+str(x2)+' '+str(y2))
        txt_file.write('\n')
    txt_file.close()
    
import glob

epoch10_model.eval()
img_names = glob.glob('./misc/lab07/Generate_dataset/images/*')

for i, file_name in enumerate(img_names):
    write(epoch10_model, file_name)
    if i % 500 == 0:
        print(i)
# Out:
# 0
# 500
# 1000

# %%
# %run ./misc/lab07/Generate_dataset/main.py
# Out:
# 66.22% = aeroplane AP
# 69.42% = bicycle AP
# 66.93% = bus AP
# 67.39% = car AP
# 75.23% = cat AP
# 76.99% = dog AP
# mAP = 70.37%

# %% [markdown]
# ### epoch15 model mAP (= Final Model)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

SMALL_VOC_CLASSES = ('aeroplane', 'bicycle', 'bus', 'car', 'cat', 'dog')
os.makedirs('predicted', exist_ok=True)

def write(model, path):
    result = []
    image = cv2.imread(path)
    h, w, _ = image.shape
    img = cv2.resize(image, (448, 448))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    transform = transforms.Compose([transforms.ToTensor(),])
    img = 2 * transform(img) - 1
    img = Variable(img[None,:,:,:],volatile=True)
    img = img.cuda()
    
    pred = model(img) #1x7x7x30
    pred = pred.cpu()
    boxes,cls_indexs,probs =  interpret_target(pred, 0)
    
    
    txt_file = open(os.path.join('predicted', os.path.basename(path)[:-4]+'.txt'), 'w')
    
    for i, box in enumerate(boxes):
        
        x1 = max(int(box[0] * w), 0)
        x2 = min(int(box[2] * w), w)
        y1 = max(int(box[1] * h), 0)
        y2 = min(int(box[3] * h), h)
        cls_index = cls_indexs[i]
        cls_index = int(cls_index)
        prob = probs[i]
        prob = float(prob)
        txt_file.write(str(SMALL_VOC_CLASSES[cls_index])+' '+'%.6f'%(prob)+' '+str(x1)+' '+str(y1)+' '+str(x2)+' '+str(y2))
        txt_file.write('\n')
    txt_file.close()
    
import glob

epoch15_model.eval()
img_names = glob.glob('./misc/lab07/Generate_dataset/images/*')

for i, file_name in enumerate(img_names):
    write(epoch15_model, file_name)
    if i % 500 == 0:
        print(i)
# Out:
# 0
# 500
# 1000

# %%
# %run ./misc/lab07/Generate_dataset/main.py
# Out:
# 65.59% = aeroplane AP
# 70.50% = bicycle AP
# 69.04% = bus AP
# 68.13% = car AP
# 76.64% = cat AP
# 76.07% = dog AP
# mAP = 71.00%

# %% [markdown]
# # Discussion
#
# ### 모델 구조
# - 네트워크는 convolutional layer들과 fully connected layer들로 구성되어 있다. 특히, 모델의 가장 앞부분에 위치한 pre-train net은 18층의 convolutional layer들로, 그 뒤를 잇는 post net은 4층의 convolutional layer들로 이루어져 있다. 각각의 conv layer 뒤에는 activation function으로 leaky relu가 사용되었는데, 이는 음의 크기를 가지는 추론 값들을 살려 둠으로써 유의미할 수 있는 정보의 손실을 막아준다. pooling은 2x2 커널 사이즈, stride 2로 행해졌으며, pre-trained net에서 총 4번 구현되었다.
#
# - Loss function은 object가 존재하는 각 grid cell들의 class prediction 값들의 sum squared error (SSE), object가 존재하며 detection에 responsible한 cell들과 그렇지 않은 cell들의 confidence score들의 SSE, 그리고 responsible한 cell들의 bounding box coordinate들의 SSE로 구성되어 있으며, 이들의 가중합으로 loss를 산정한다. Bounding box coordinate들의 오차에는 가중치를 5로 상대적으로 크게 두는 한편, detection과 무관한 cell들의 confidence score에 대한 가중치는 0.5로 상대적으로 작게 두었다. 이는 좌표값의 오차가 상대적으로 작게 나타나지만 중요도는 크기 때문이며, 무관한 cell들의 개수는 매우 많으나 이들의 confidence score 오차는 학습에 덜 반영되어야 하기 때문이다. 그리고 width와 height의 오차는 제곱근을 취한 후 구하였다. 이는 정확한 x와 y의 좌표에 대한 오차를 w나 h의 오차보다 더 중요시하겠다는 의미와 같다.
#
#
# ### 실험 결과
# - 15 epoch에 걸쳐 학습을 시켰을 때 초기 loss는 약 0.67로 나타났고, 학습을 거듭할수록 0.5를 약간 상회하는 값에서 loss가 수렴하였다. epoch 5에서부터 loss값이 개선되지 않고 0.5 이하로 떨어지지 않는 모습을 보였다.
#
# - loss의 수렴 이후 학습에 따른 성능 개선이 있는지, 그리고 overfitting 등으로 인해 성능이 감소되는지 확인하기 위해 각각 epoch 5, 10, 15, 그리고 최소 loss에서의 weight들을 저장하여 각각의 성능을 비교해 보았다.
#
# - 우선 각 모델들에 임의로 이미지 10장을 전달해 주고 average precision (AP)를 비교했다. AP값들은 전반적으로 epoch 15가 가장 뛰어나고, 최소 loss, epoch 10, epoch 5 모델 순으로 나타났다.
#
# - Test set에 있는 모든 이미지들에 대한 각 모델들의 mean average precision (mAP) 역시 비교해 보았다. mAP 값 역시 epoch 15가 가장 뛰어나고, 최소 loss, epoch 10, epoch 5 모델 순으로 높은 성능을 보였다. 더 나아가, epoch 15 모델과 최소 loss 모델은 mAP가 각각 71.00%, 70.08%를 보이며 기준치인 69 mAP를 유의미한 값으로 상회하였고, epoch 10, epoch 5 모델들의 mAP 역시 70.37%, 69.24%로 기준 mAP인 69%의 성능을 상회하였다.
#
# - mAP 결과를 보면, epoch 5, 10, 15를 거치면서 mAP 값은 지속적으로 향상되는 것을 볼 수 있다. 이를 통해 overfitting 등을 통한 성능 감소는 현재 15 epoch에 걸친 학습 결과에는 영향을 미치지 않은 것으로 보인다. 그러나, 최소 loss 모델이 최종 15 epoch 학습 모델보다 mAP 성능이 낮게 나왔다. 이는 loss의 감소가 더 이상 성능의 향상을 대변 혹은 보장하지 못하는 상황으로 해석할 수 있으며 15 epoch를 넘겨 계속 학습을 시킨다면 overfitting의 영향으로 성능이 감소할 가능성이 있다.
#
# - 15 epoch 동안 training을 하며 얻은 최종 모델(epoch 15 model)과, 최소 loss를 기록했던 모델의 임의의 이미지에 대한 inference visualization 결과를 대조해 보았다. 두 모델 모두 물체가 한 개만 존재하는 이미지들(각 1번째와 4번째 사진들)에서 bounding box prediction과 class prediction이 상당히 정확한 결과를 보였다. 한편, 물체 여러 개가 겹쳐 있거나 작은 물체들이 여러 개 있는 이미지들(각 2, 3, 5번째 사진들)의 경우, 겹쳐진 물체들을 제대로 인식하지 못하여, 겹친 물체들의 bounding box prediction과 class prediction이 나타나지 않는 경우를 확인할 수 있었다. 심지어 3번째 사진의 경우 사진 안에 위치한 모든 객체들의 bounding box와 class predicion이 나타나지 않았다.
#
# - 이러한 결과는 YOLO의 작동 방식에서 기인하는데, YOLO의 loss function에서는 각 grid cell에서 특정 객체에 대해 추론한 bounding box들 중에서 ground truth와의 IoU 값이 가장 크게 나타나는 box를 'responsible'한 box라고 정하여 이를 학습에 사용한다. 이때, responsible한 grid cell은 하나의 객체만을 탐지하기 때문에 여러 객체가 겹쳐 있는 경우 이를 동일한 grid cell에서 처리할 수가 없게 된다. 또한, 객체의 크기가 작은 경우 bounding box의 위치가 조금이라도 변한다면 IoU 값이 영향을 많이 받게 되기 때문에 작은 물체나 겹쳐진 물체는 detect하기 어려운 것이다.
